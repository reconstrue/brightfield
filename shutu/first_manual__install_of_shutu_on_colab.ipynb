# %% [markdown]
# # Initial Probings: Installing ShuTu SWC generation on Colab
#
# This document is a verbose blow-by-blow of getting ShuTu to run on Colab on 2019-10-12, following the instructions in the ShuTu tutorial. This proves that ShuTu can be used on Colab.
#
# Having an archive of the chore is good info to keep, but for actually using ShuTu on The Allen Institute's Brightfield challenge dataset, a much terser and easier to use set of instructions ave been generated. For that see, [install_shutu_on_colab.ipynb](https://colab.research.google.com/drive/1wRnt5ceTs2Oau4g_BiYv09ZOLbv3cyWI#scrollTo=Q1eCY1mvHbCr)
#
#
# For context and further explanation, see [brightfield neuron reconstruction challenge](https://colab.research.google.com/drive/1qvwT-SxHpZSLQ88VeIOkR296pbZfQqTK#scrollTo=UHFoENqqYV65). The context includes a tool to view the generated SWC skeleton file and compare it to a manually generated "gold standard" skeleton. This notebook just generates the SWC files, on Colab.
#
# ## Status
# - Sat 2019-10-12:
#   - Actually started on code.
#   - Tested if deployable on Colab: yup, with a bit of fanegling.
#     - ShuTu SWC generator works on Colab.
#     - ShuTu UI is not Jupyter-based.
#   - Stopped developing this. Keeping it as archive of what happened.
# - Fri 2019-10-11:
#   - Inited this file.
#   - Started as an empty Python 3 notebook.

# %% [markdown]
# ## Install ShuTu on Colab
#
# This is a log of a (successful) attempt to install ShuTu on Colab, following the instruction in [the ShuTu tutorial](http://personal.psu.edu/dzj2/ShuTu/).

# %%
# See ShuTu tutorial, "Installation" section, which has 
# text "Download Linux installer ShuTuUbuntu" which
# links to the following zip file.

# Get the Linux distro of ShuTu (took less than a minute to DL)
# !wget https://psu.box.com/shared/static/wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
# Out:
# --2019-10-13 18:22:09--  https://psu.box.com/shared/static/wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
# Resolving psu.box.com (psu.box.com)... 107.152.27.197, 107.152.26.197
# Connecting to psu.box.com (psu.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip [following]
# --2019-10-13 18:22:09--  https://psu.box.com/public/static/wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
# Reusing existing connection to psu.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://psu.app.box.com/public/static/wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip [following]
# --2019-10-13 18:22:10--  https://psu.app.box.com/public/static/wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
# Resolving psu.app.box.com (psu.app.box.com)... 107.152.25.199
# Connecting to psu.app.box.com (psu.app.box.com)|107.152.25.199|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!0rCgxYCHqERBEMFYn7dS8VJm8Z7uTWxVJn8gePdTharsa2l8YUT8RH-Hk93kiMrfTjx2mxBIRpb2I21ZH-pLbo55equzJwmULmxfwIW3lytzWIloZ-6jeK8CN0QSIIWstNPvqy5OTPC4bPJOacRJA3GRgRDqxI2hxdaTH4T7Bq6Spa31MZZSGuBDYmOs44sbRnYN49Up2l1vkz5NwqEtCYwcWx7-tOoX47XR31T7Kf6TmjGBJkxg1npWOn6n9iN3fRusubsqvC4TrkDhI4ACeFPwp5cfn5bYkjY2zNlM2t_QxKw6JEHt5PERT2zfLAbDWTwWZoASIo6Og2XVfcpeiDSKLUYZ-7c_vhQjIx_jmymMKeqqPfv9bSyEgkNmyJeuSMluERwqIoxQ__0wV379g0IGQWHizvNz_zcfhztaIbJM3gMJbZy1FJbmDq4CqQIOKejrPm3r8ZXpPj1W7i3863Jhh6xVgHpidTFVpYmtFJOcAjAMohFyMz1ipnaEM3NPf9W0W1LvrDqtBfFqYa3AohgM8cAFXO4vT6Y6DU69DBryivL4JO0bE2VFacrHTEiYz6BdgetcD4lZh83hNaiyChPfqqbDr767JLGeiBnDpJ0kBj6uurs-BfJeWwYNzusLWjRfPW_AM_fSfJtwupowyGz6hg5bbE9GTJNbxwtiaPkFhtnpFzQftu-Ym0fGq-KkG4K4uj-JG6QCKDs2gaa_U2PMI-KCO4He63ZmwDuheL6zGHADAuPk65AvR1QoLuPz5QvlCibnJp0IeFPQ1fE0piptGsmvoT7Ydt2dPeU_gE2SY8MP0o10P4RkA0r3CKz7qLmF5PvyDHWcLjJ-CpF3Qt1SsWnmkLXAD4WbE4fchMjga1XVy_-E3GciotnZu76b8Ws6Na8pOmTblxYdwThKLMxoyw4mn9fQl66hdnjlfb9PSSILsEY5q2B946q6RRAdo7ZKi3DsnTIZAxzWZmOGpB0WRYPilboDohGxPlu-udDFkLXvs3opclmNtdJ8mehP4IMtXA5b9sMGvYbwrHitUe0TpmtmyRekmQ8jFWEfOTVB8cGCLkXREjhra0Pu0eSr22cu6c1KqZkqahnOh0_ftF_gCZ2f4SjTHgpWzvrxK1ZZVswIsGt3p8w5blXH_u9INWcGO4bVO9mg0bmD8050KZOZRsfTS00_0IB8QkgZij2yF76rdqceT0jhypAQv_6aPAnRFvyjDDen6IUjm3no-cg6_x615YIv4Pw-rRAfiszaaCXPCdwVac35FjMrwF7p1qXGvtHZNI7Mak8z_cXb-OMPbYqs6Cog1Dsnods7JRnJVspp785EJIqZQRzq0ijmCrLEjR3aKZgdoJwzQ7jbSRSavV3-HST_8VF3tHGYRraN78ApSlCWELo./download [following]
# --2019-10-13 18:22:10--  https://public.boxcloud.com/d/1/b1!0rCgxYCHqERBEMFYn7dS8VJm8Z7uTWxVJn8gePdTharsa2l8YUT8RH-Hk93kiMrfTjx2mxBIRpb2I21ZH-pLbo55equzJwmULmxfwIW3lytzWIloZ-6jeK8CN0QSIIWstNPvqy5OTPC4bPJOacRJA3GRgRDqxI2hxdaTH4T7Bq6Spa31MZZSGuBDYmOs44sbRnYN49Up2l1vkz5NwqEtCYwcWx7-tOoX47XR31T7Kf6TmjGBJkxg1npWOn6n9iN3fRusubsqvC4TrkDhI4ACeFPwp5cfn5bYkjY2zNlM2t_QxKw6JEHt5PERT2zfLAbDWTwWZoASIo6Og2XVfcpeiDSKLUYZ-7c_vhQjIx_jmymMKeqqPfv9bSyEgkNmyJeuSMluERwqIoxQ__0wV379g0IGQWHizvNz_zcfhztaIbJM3gMJbZy1FJbmDq4CqQIOKejrPm3r8ZXpPj1W7i3863Jhh6xVgHpidTFVpYmtFJOcAjAMohFyMz1ipnaEM3NPf9W0W1LvrDqtBfFqYa3AohgM8cAFXO4vT6Y6DU69DBryivL4JO0bE2VFacrHTEiYz6BdgetcD4lZh83hNaiyChPfqqbDr767JLGeiBnDpJ0kBj6uurs-BfJeWwYNzusLWjRfPW_AM_fSfJtwupowyGz6hg5bbE9GTJNbxwtiaPkFhtnpFzQftu-Ym0fGq-KkG4K4uj-JG6QCKDs2gaa_U2PMI-KCO4He63ZmwDuheL6zGHADAuPk65AvR1QoLuPz5QvlCibnJp0IeFPQ1fE0piptGsmvoT7Ydt2dPeU_gE2SY8MP0o10P4RkA0r3CKz7qLmF5PvyDHWcLjJ-CpF3Qt1SsWnmkLXAD4WbE4fchMjga1XVy_-E3GciotnZu76b8Ws6Na8pOmTblxYdwThKLMxoyw4mn9fQl66hdnjlfb9PSSILsEY5q2B946q6RRAdo7ZKi3DsnTIZAxzWZmOGpB0WRYPilboDohGxPlu-udDFkLXvs3opclmNtdJ8mehP4IMtXA5b9sMGvYbwrHitUe0TpmtmyRekmQ8jFWEfOTVB8cGCLkXREjhra0Pu0eSr22cu6c1KqZkqahnOh0_ftF_gCZ2f4SjTHgpWzvrxK1ZZVswIsGt3p8w5blXH_u9INWcGO4bVO9mg0bmD8050KZOZRsfTS00_0IB8QkgZij2yF76rdqceT0jhypAQv_6aPAnRFvyjDDen6IUjm3no-cg6_x615YIv4Pw-rRAfiszaaCXPCdwVac35FjMrwF7p1qXGvtHZNI7Mak8z_cXb-OMPbYqs6Cog1Dsnods7JRnJVspp785EJIqZQRzq0ijmCrLEjR3aKZgdoJwzQ7jbSRSavV3-HST_8VF3tHGYRraN78ApSlCWELo./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 295628950 (282M) [application/zip]
# Saving to: ‘wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip’
#
# wszpq3r6hwgoxo8eq0v 100%[===================>] 281.93M  19.7MB/s    in 15s
#
# 2019-10-13 18:22:26 (18.9 MB/s) - ‘wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip’ saved [295628950/295628950]

# %%
# %%shell
#
# # There should now be a zip file on Colab VM now:
# pwd
# ls
# unzip wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
# Out:
# /content
# sample_data  wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
# Archive:  wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip
#    creating: ShuTuUbuntu/
#   inflating: ShuTuUbuntu/ShuTu.Parameters.granule63XTest.dat
#   inflating: ShuTuUbuntu/processImages.c
#   inflating: ShuTuUbuntu/makefile
#   inflating: ShuTuUbuntu/tinydir.h
#   inflating: ShuTuUbuntu/ShuTu.Parameters.100X.dat
#   inflating: ShuTuUbuntu/scaleSWC.c
#   inflating: ShuTuUbuntu/ShuTu.Parameters.flyMotorNeuron.dat
#    creating: ShuTuUbuntu/llist/
#   inflating: ShuTuUbuntu/llist/setup.py
#    creating: ShuTuUbuntu/llist/src/
#   inflating: ShuTuUbuntu/llist/src/llist.c
#   inflating: ShuTuUbuntu/llist/src/dllist.c
#   inflating: ShuTuUbuntu/llist/src/py23macros.h
#   inflating: ShuTuUbuntu/llist/src/sllist.c
#   inflating: ShuTuUbuntu/llist/src/sllist.h
#   inflating: ShuTuUbuntu/llist/src/dllist.h
#   inflating: ShuTuUbuntu/llist/MANIFEST.in
#   inflating: ShuTuUbuntu/llist/LICENSE
#    creating: ShuTuUbuntu/llist/docs/
#   inflating: ShuTuUbuntu/llist/docs/conf.py
#   inflating: ShuTuUbuntu/llist/docs/make.bat
#   inflating: ShuTuUbuntu/llist/docs/Makefile
#   inflating: ShuTuUbuntu/llist/docs/index.rst
#   inflating: ShuTuUbuntu/llist/PKG-INFO
#   inflating: ShuTuUbuntu/llist/MANIFEST
#    creating: ShuTuUbuntu/llist/examples/
#   inflating: ShuTuUbuntu/llist/examples/lucky_numbers.py
#   inflating: ShuTuUbuntu/llist/Makefile
#   inflating: ShuTuUbuntu/llist/README
#    creating: ShuTuUbuntu/llist/tests/
#   inflating: ShuTuUbuntu/llist/tests/speed_test.py
#   inflating: ShuTuUbuntu/llist/tests/llist_test.py
#    creating: ShuTuUbuntu/llist/build/
#    creating: ShuTuUbuntu/llist/build/temp.linux-x86_64-2.7/
#    creating: ShuTuUbuntu/llist/build/temp.linux-x86_64-2.7/src/
#    creating: ShuTuUbuntu/llist/build/lib.linux-x86_64-2.7/
#   inflating: ShuTuUbuntu/llist/build/lib.linux-x86_64-2.7/llist.so
#   inflating: ShuTuUbuntu/llist/CHANGES
#   inflating: ShuTuUbuntu/build.sh
#   inflating: ShuTuUbuntu/createTiffStacksZeiss.c
#   inflating: ShuTuUbuntu/analyzeNEO.py
#   inflating: ShuTuUbuntu/libShuTu.c
#    creating: ShuTuUbuntu/mylib/
#   inflating: ShuTuUbuntu/mylib/swc.p
#   inflating: ShuTuUbuntu/mylib/hash.c
#   inflating: ShuTuUbuntu/mylib/level.set.p
#   inflating: ShuTuUbuntu/mylib/region.c
#    creating: ShuTuUbuntu/mylib/generator.dSYM/
#    creating: ShuTuUbuntu/mylib/generator.dSYM/Contents/
#    creating: ShuTuUbuntu/mylib/generator.dSYM/Contents/Resources/
#    creating: ShuTuUbuntu/mylib/generator.dSYM/Contents/Resources/DWARF/
#   inflating: ShuTuUbuntu/mylib/generator.dSYM/Contents/Resources/DWARF/generator
#   inflating: ShuTuUbuntu/mylib/generator.dSYM/Contents/Info.plist
#    creating: ShuTuUbuntu/mylib/MY_TIFF/
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/utilities.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/app.show.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/INDEX
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/app.tagger.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/utilities.h
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiff.io.p
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiffRGB
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tifftagger
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/generator.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiff.io.h
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiff.image.h
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiff.image.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiff.io.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiffconvert
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiff.image.p
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/utilities.p
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/Makefile
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/app.convert.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/README
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/mrc2tiff
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/CMakeLists.txt
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/tiffshow
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/app.mrc2.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/app.tagger.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/app.color.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/generator.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/INDEX.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/tiff.io.h.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/CMakeLists.txt.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/README.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/Makefile.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/tiff.io.p.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/tiff.image.p.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/tiff.image.h.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/app.show.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/app.convert.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/utilities.h.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/text-base/utilities.p.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/dir-prop-base
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/.svn/entries
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/prop-base/
#    creating: ShuTuUbuntu/mylib/MY_TIFF/.svn/props/
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/app.color.c
#   inflating: ShuTuUbuntu/mylib/MY_TIFF/app.mrc2.c
#   inflating: ShuTuUbuntu/mylib/regionToLabelMask.c
#   inflating: ShuTuUbuntu/mylib/linear.algebra.h
#   inflating: ShuTuUbuntu/mylib/utilities.c
#   inflating: ShuTuUbuntu/mylib/image.p
#   inflating: ShuTuUbuntu/mylib/utilities.h
#   inflating: ShuTuUbuntu/mylib/swc.h
#   inflating: ShuTuUbuntu/mylib/paths.p
#   inflating: ShuTuUbuntu/mylib/draw.p
#   inflating: ShuTuUbuntu/mylib/swc.c
#   inflating: ShuTuUbuntu/mylib/histogram.h
#   inflating: ShuTuUbuntu/mylib/sampsep.c
#   inflating: ShuTuUbuntu/mylib/array.c
#   inflating: ShuTuUbuntu/mylib/generator.c
#    creating: ShuTuUbuntu/mylib/MY_FFT/
#   inflating: ShuTuUbuntu/mylib/MY_FFT/fft.D.h
#   inflating: ShuTuUbuntu/mylib/MY_FFT/test.norm.D.c
#   inflating: ShuTuUbuntu/mylib/MY_FFT/test.fft.c
#   inflating: ShuTuUbuntu/mylib/MY_FFT/fft.F.c
#   inflating: ShuTuUbuntu/mylib/MY_FFT/test.norm.F.c
#   inflating: ShuTuUbuntu/mylib/MY_FFT/myfft.c
#   inflating: ShuTuUbuntu/mylib/MY_FFT/Makefile
#   inflating: ShuTuUbuntu/mylib/MY_FFT/fft.D.c
#   inflating: ShuTuUbuntu/mylib/MY_FFT/README
#   inflating: ShuTuUbuntu/mylib/MY_FFT/CMakeLists.txt
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/fft.D.h.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/fft.F.h.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/test.fft.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/myfft.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/test.norm.D.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/fft.D.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/CMakeLists.txt.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/fft.F.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/README.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/Makefile.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/text-base/test.norm.F.c.svn-base
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/MY_FFT/.svn/entries
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/prop-base/
#    creating: ShuTuUbuntu/mylib/MY_FFT/.svn/props/
#   inflating: ShuTuUbuntu/mylib/MY_FFT/fft.F.h
#   inflating: ShuTuUbuntu/mylib/sampsepNA.c
#   inflating: ShuTuUbuntu/mylib/fft.p
#   inflating: ShuTuUbuntu/mylib/.DS_Store
#   inflating: ShuTuUbuntu/mylib/draw.h
#   inflating: ShuTuUbuntu/mylib/water.shed.h
#   inflating: ShuTuUbuntu/mylib/histogram.p
#   inflating: ShuTuUbuntu/mylib/Makefile.backup
#   inflating: ShuTuUbuntu/mylib/region.h
#   inflating: ShuTuUbuntu/mylib/fct.min.h
#   inflating: ShuTuUbuntu/mylib/array.h
#   inflating: ShuTuUbuntu/mylib/snake.p
#   inflating: ShuTuUbuntu/mylib/sampsepNALoadRaw16.c
#   inflating: ShuTuUbuntu/mylib/hash.h
#   inflating: ShuTuUbuntu/mylib/level.set.c
#   inflating: ShuTuUbuntu/mylib/fct.root.h
#   inflating: ShuTuUbuntu/mylib/histogram.c
#   inflating: ShuTuUbuntu/mylib/sampsepNALoadSaveRaw.c
#   inflating: ShuTuUbuntu/mylib/cdf.p
#   inflating: ShuTuUbuntu/mylib/water.shed.c
#   inflating: ShuTuUbuntu/mylib/filters.c
#   inflating: ShuTuUbuntu/mylib/level.set.h
#   inflating: ShuTuUbuntu/mylib/hash.p
#   inflating: ShuTuUbuntu/mylib/linear.algebra.p
#   inflating: ShuTuUbuntu/mylib/water.shed.p
#   inflating: ShuTuUbuntu/mylib/filters.p
#   inflating: ShuTuUbuntu/mylib/utilities.p
#   inflating: ShuTuUbuntu/mylib/fct.root.p
#   inflating: ShuTuUbuntu/mylib/connectivity.p
#   inflating: ShuTuUbuntu/mylib/image.c
#   inflating: ShuTuUbuntu/mylib/fft.h
#   inflating: ShuTuUbuntu/mylib/fct.min.p
#   inflating: ShuTuUbuntu/mylib/Makefile
#   inflating: ShuTuUbuntu/mylib/region.p
#   inflating: ShuTuUbuntu/mylib/filters.h
#   inflating: ShuTuUbuntu/mylib/CMakeLists.txt
#   inflating: ShuTuUbuntu/mylib/paths.c
#   inflating: ShuTuUbuntu/mylib/mylib.p
#   inflating: ShuTuUbuntu/mylib/paths.h
#   inflating: ShuTuUbuntu/mylib/connectivity.c
#   inflating: ShuTuUbuntu/mylib/copy.sh
#   inflating: ShuTuUbuntu/mylib/cdf.h
#   inflating: ShuTuUbuntu/mylib/svg.c
#   inflating: ShuTuUbuntu/mylib/image.h
#    creating: ShuTuUbuntu/mylib/old/
#    creating: ShuTuUbuntu/mylib/old/20110802/
#   inflating: ShuTuUbuntu/mylib/old/20110802/sampsepNA
#   inflating: ShuTuUbuntu/mylib/old/20110802/sampsepNA.c
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/old/20110802/.svn/text-base/sampsepNA.svn-base
#   inflating: ShuTuUbuntu/mylib/old/20110802/.svn/text-base/sampsepNA.c.svn-base
#   inflating: ShuTuUbuntu/mylib/old/20110802/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/old/20110802/.svn/entries
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/prop-base/
#   inflating: ShuTuUbuntu/mylib/old/20110802/.svn/prop-base/sampsepNA.svn-base
#  extracting: ShuTuUbuntu/mylib/old/20110802/.svn/prop-base/sampsepNA.c.svn-base
#    creating: ShuTuUbuntu/mylib/old/20110802/.svn/props/
#   inflating: ShuTuUbuntu/mylib/old/sampsepNA.c.20110815
#    creating: ShuTuUbuntu/mylib/old/.svn/
#    creating: ShuTuUbuntu/mylib/old/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/old/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/old/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/old/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/old/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/old/.svn/text-base/sampsepNA.c.20110815.svn-base
#   inflating: ShuTuUbuntu/mylib/old/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/old/.svn/entries
#    creating: ShuTuUbuntu/mylib/old/.svn/prop-base/
#  extracting: ShuTuUbuntu/mylib/old/.svn/prop-base/sampsepNA.c.20110815.svn-base
#    creating: ShuTuUbuntu/mylib/old/.svn/props/
#   inflating: ShuTuUbuntu/mylib/mylib.h
#   inflating: ShuTuUbuntu/mylib/sampsepNALoadRaw.c
#   inflating: ShuTuUbuntu/mylib/array.p
#    creating: ShuTuUbuntu/mylib/.svn/
#    creating: ShuTuUbuntu/mylib/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/filters.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/draw.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/image.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/hash.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/histogram.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/sampsep.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/linear.algebra.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/array.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/fct.min.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/swc.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/copy.sh.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/filters.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/fft.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/fct.root.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/sampsepNALoadSaveRaw.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/generator.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/paths.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/swc.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/paths.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/fct.min.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/sampsepNALoadRaw16.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/image.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/fft.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/snake.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/level.set.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/CMakeLists.txt.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/mylib.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/sampsepNALoadRaw.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/regionToLabelMask.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/Makefile.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/water.shed.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/water.shed.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/level.set.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/linear.algebra.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/connectivity.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/cdf.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/sampsepNA.c.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/fct.root.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/utilities.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/svg.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/utilities.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/array.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/draw.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/region.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/mylib.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/hash.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/histogram.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/cdf.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/connectivity.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/svg.p.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/text-base/region.h.svn-base
#   inflating: ShuTuUbuntu/mylib/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/.svn/dir-prop-base
#   inflating: ShuTuUbuntu/mylib/.svn/entries
#    creating: ShuTuUbuntu/mylib/.svn/prop-base/
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/sampsep.c.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/copy.sh.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/filters.h.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/sampsepNALoadSaveRaw.c.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/sampsepNALoadRaw16.c.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/sampsepNALoadRaw.c.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/regionToLabelMask.c.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/water.shed.p.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/water.shed.h.svn-base
#  extracting: ShuTuUbuntu/mylib/.svn/prop-base/sampsepNA.c.svn-base
#    creating: ShuTuUbuntu/mylib/.svn/props/
#   inflating: ShuTuUbuntu/mylib/fct.root.c
#   inflating: ShuTuUbuntu/mylib/snake.c
#   inflating: ShuTuUbuntu/mylib/svg.h
#   inflating: ShuTuUbuntu/mylib/fft.c
#   inflating: ShuTuUbuntu/mylib/svg.p
#   inflating: ShuTuUbuntu/mylib/connectivity.h
#   inflating: ShuTuUbuntu/mylib/cdf.c
#   inflating: ShuTuUbuntu/mylib/linear.algebra.c
#   inflating: ShuTuUbuntu/mylib/draw.c
#   inflating: ShuTuUbuntu/mylib/mylib.c
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/Mylib.Powerpoint.ppt
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/text-base/Mylib.Powerpoint.ppt.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/entries
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/prop-base/
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/prop-base/Mylib.Powerpoint.ppt.svn-base
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/.svn/props/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PPT/._Mylib.Powerpoint.ppt
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/.DS_Store
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/mydoc.css
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Connectivity.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Image.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Slice.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Shortest.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Linear.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/AllFunctions.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Function.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Frame.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Level_Tree.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Distance.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Partition.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Array.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Convolver.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/SVG.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/AForm.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Draw.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/System.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/LU_Factor.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Region.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Histogram.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/CDF.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Root.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Watershed.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Tiff.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Fast.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Hash_Table.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Generic.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Filters.html
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/SVG.Fonts.svg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/Border.Extend.jpg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/Border.Wrap.jpg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/SVG.Colors.svg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/Border.Zero.jpg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/SVG.Join.Styles.svg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/Surfaces.jpg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/SVG.Arrows.svg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/Border.Reflect.jpg
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/Border.Zero.jpg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/SVG.Colors.svg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/Border.Extend.jpg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/Border.Reflect.jpg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/SVG.Join.Styles.svg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/SVG.Cap.Styles.svg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/SVG.Arrows.svg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/Surfaces.jpg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/Border.Invert.jpg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/Border.Wrap.jpg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/text-base/SVG.Fonts.svg.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/entries
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/Border.Zero.jpg.svn-base
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/Border.Extend.jpg.svn-base
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/Border.Reflect.jpg.svn-base
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/Surfaces.jpg.svn-base
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/Border.Invert.jpg.svn-base
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/prop-base/Border.Wrap.jpg.svn-base
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/.svn/props/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/Border.Invert.jpg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/IMAGES/SVG.Cap.Styles.svg
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/AllPages.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/SWC_Tree.html
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/AllPages.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Image.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/AllFunctions.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Root.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Generic.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Mylib.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Level_Tree.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Tiff.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Slice.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Hash_Table.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Band_Factor.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/AForm.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Array.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Region.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Function.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Draw.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Fast.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/SWC_Tree.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/mydoc.css.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Linear.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Shortest.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Frame.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Distance.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Partition.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Filters.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Histogram.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/LU_Factor.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Connectivity.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/System.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Watershed.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Convolver.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/CDF.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/SVG.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/text-base/Correlation.html.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/entries
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/.svn/props/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Mylib.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Correlation.html
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/HTML/Band_Factor.html
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/Object.Management.pdf
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/._Object.Management.pdf
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/Command.Line.pdf
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/text-base/Object.Management.pdf.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/text-base/Command.Line.pdf.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/entries
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/prop-base/
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/prop-base/Object.Management.pdf.svn-base
#  extracting: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/prop-base/Command.Line.pdf.svn-base
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/PDFS/.svn/props/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/BUILDME
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/tmp/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/tmp/text-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/tmp/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/tmp/props/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/text-base/
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/text-base/BUILDME.svn-base
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/all-wcprops
#   inflating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/entries
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/prop-base/
#    creating: ShuTuUbuntu/mylib/DOCUMENTS/.svn/props/
#   inflating: ShuTuUbuntu/mylib/fct.min.c
#   inflating: ShuTuUbuntu/ShuTuAutoTrace.c
#   inflating: ShuTuUbuntu/ShuTu.Parameters.Purkinje.dat
#   inflating: ShuTuUbuntu/libShuTu.h
#   inflating: ShuTuUbuntu/scaleSWC.py
#   inflating: ShuTuUbuntu/stitchTiles.c
#   inflating: ShuTuUbuntu/ShuTu.Parameters.63X.dat
#    creating: ShuTuUbuntu/distro/
#   inflating: ShuTuUbuntu/distro/~22-24-1-7.autosave.swc
#   inflating: ShuTuUbuntu/distro/ShuTu
#    creating: ShuTuUbuntu/distro/lib/
#   inflating: ShuTuUbuntu/distro/lib/libquadmath.so
#   inflating: ShuTuUbuntu/distro/lib/libstdc++.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_omp.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_threads.so.3.5.7
#   inflating: ShuTuUbuntu/distro/lib/libhdf5.la
#   inflating: ShuTuUbuntu/distro/lib/libQtCore.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libQtScript.prl
#   inflating: ShuTuUbuntu/distro/lib/libgraphite2.so.3.2.1
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_threads.la
#   inflating: ShuTuUbuntu/distro/lib/libicudata.so.58
#   inflating: ShuTuUbuntu/distro/lib/libcairo.la
#   inflating: ShuTuUbuntu/distro/lib/libQtSvg.so
#   inflating: ShuTuUbuntu/distro/lib/libjpeg.a
#   inflating: ShuTuUbuntu/distro/lib/libpangocairo-1.0.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_omp.a
#   inflating: ShuTuUbuntu/distro/lib/libQtMultimedia.la
#   inflating: ShuTuUbuntu/distro/lib/libasprintf.so.0
#    creating: ShuTuUbuntu/distro/lib/pkgconfig/
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/fftw3.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libpng.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/openssl.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/graphite2.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtCLucene.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libpcrecpp.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gmodule-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-xlib-xrender.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtDeclarative.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtScript.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/glib-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-xlib.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/zlib.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/pangoft2.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/jansson.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtGui.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtSql.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libxml-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/icu-io.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtTest.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/freetype2.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libtiff-4.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gio-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/pango.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libcrypto.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtDesignerComponents.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/fftw3l.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/harfbuzz-subset.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-svg.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gthread-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtScriptTools.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/fftw3f.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/icu-uc.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtWebKit.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/harfbuzz.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/pangocairo.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-ps.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-png.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libssl.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtSvg.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtXml.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-script.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/pixman-1.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtDesigner.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libjpeg.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/liblzma.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtMultimedia.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-fc.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gobject-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gmodule-no-export-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtDBus.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/icu-i18n.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtOpenGL.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/fontconfig.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gio-unix-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtUiTools.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/harfbuzz-icu.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/gmodule-export-2.0.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/harfbuzz-gobject.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-ft.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libpcre.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtCore.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libffi.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-gobject.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtNetwork.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtHelp.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/cairo-pdf.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/QtXmlPatterns.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libpcreposix.pc
#   inflating: ShuTuUbuntu/distro/lib/pkgconfig/libpng16.pc
#   inflating: ShuTuUbuntu/distro/lib/libQtHelp.la
#   inflating: ShuTuUbuntu/distro/lib/libQtTest.so
#   inflating: ShuTuUbuntu/distro/lib/libcairo-script-interpreter.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_omp.so.3
#   inflating: ShuTuUbuntu/distro/lib/libpango-1.0.la
#   inflating: ShuTuUbuntu/distro/lib/libicuio.so.58
#   inflating: ShuTuUbuntu/distro/lib/libQtMultimedia.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libpixman-1.la
#   inflating: ShuTuUbuntu/distro/lib/libfreetype.so
#   inflating: ShuTuUbuntu/distro/lib/libffi.a
#   inflating: ShuTuUbuntu/distro/lib/libQtMultimedia.prl
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-gobject.so
#   inflating: ShuTuUbuntu/distro/lib/libglib-2.0.so
#   inflating: ShuTuUbuntu/distro/lib/libQtSvg.prl
#   inflating: ShuTuUbuntu/distro/lib/libQtTest.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libpng16.la
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_omp.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libQtTest.so.4
#   inflating: ShuTuUbuntu/distro/lib/libgfortran.so.3.0.0
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl.so
#   inflating: ShuTuUbuntu/distro/lib/libQtGui.prl
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f.la
#   inflating: ShuTuUbuntu/distro/lib/libQtDesignerComponents.so.4
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_omp.a
#   inflating: ShuTuUbuntu/distro/lib/libQtNetwork.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f.so.3.5.7
#   inflating: ShuTuUbuntu/distro/lib/libQtNetwork.prl
#   inflating: ShuTuUbuntu/distro/lib/libQtOpenGL.so.4
#   inflating: ShuTuUbuntu/distro/lib/libQtXml.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libQtDesignerComponents.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_omp.a
#   inflating: ShuTuUbuntu/distro/lib/libpcre.so.1
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_omp.so.3
#   inflating: ShuTuUbuntu/distro/lib/libicutest.so.58
#   inflating: ShuTuUbuntu/distro/lib/libxml2.a
#   inflating: ShuTuUbuntu/distro/lib/libgio-2.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libgobject-2.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libz.a
#   inflating: ShuTuUbuntu/distro/lib/libgettextpo.la
#   inflating: ShuTuUbuntu/distro/lib/libcharset.so.1
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-gobject.so.0.10400.3
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_threads.so
#   inflating: ShuTuUbuntu/distro/lib/libicutest.so
#   inflating: ShuTuUbuntu/distro/lib/libgio-2.0.so.0.5104.0
#   inflating: ShuTuUbuntu/distro/lib/libicui18n.so.58.2
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_cpp.la
#   inflating: ShuTuUbuntu/distro/lib/libubsan.so.1
#   inflating: ShuTuUbuntu/distro/lib/libQtSql.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-icu.so
#   inflating: ShuTuUbuntu/distro/lib/libpangocairo-1.0.la
#   inflating: ShuTuUbuntu/distro/lib/libfontconfig.so.1.9.2
#   inflating: ShuTuUbuntu/distro/lib/libpcreposix.la
#   inflating: ShuTuUbuntu/distro/lib/libstdc++.so.6.0.25
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f.a
#   inflating: ShuTuUbuntu/distro/lib/libQtMultimedia.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/liblzma.a
#   inflating: ShuTuUbuntu/distro/lib/libgobject-2.0.la
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-subset.la
#   inflating: ShuTuUbuntu/distro/lib/libQtDesigner.prl
#   inflating: ShuTuUbuntu/distro/lib/libicui18n.a
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_threads.la
#   inflating: ShuTuUbuntu/distro/lib/libQtScript.la
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_threads.la
#   inflating: ShuTuUbuntu/distro/lib/libpixman-1.a
#   inflating: ShuTuUbuntu/distro/lib/libgmodule-2.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libhdf5.a
#   inflating: ShuTuUbuntu/distro/lib/libQtDesigner.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libicuio.so.58.2
#   inflating: ShuTuUbuntu/distro/lib/libQtMultimedia.so.4
#   inflating: ShuTuUbuntu/distro/lib/libicui18n.so.58
#   inflating: ShuTuUbuntu/distro/lib/libQtHelp.prl
#   inflating: ShuTuUbuntu/distro/lib/libxml2.so
#   inflating: ShuTuUbuntu/distro/lib/libcharset.so.1.0.0
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz.so.0
#   inflating: ShuTuUbuntu/distro/lib/xml2Conf.sh
#   inflating: ShuTuUbuntu/distro/lib/libpng16.so
#   inflating: ShuTuUbuntu/distro/lib/libQtSql.prl
#   inflating: ShuTuUbuntu/distro/lib/libQtOpenGL.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/preloadable_libiconv.so
#   inflating: ShuTuUbuntu/distro/lib/libQtDeclarative.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libicutu.a
#   inflating: ShuTuUbuntu/distro/lib/libgettextpo.so
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl_cpp.a
#   inflating: ShuTuUbuntu/distro/lib/libQtCore.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_threads.so.3.5.7
#   inflating: ShuTuUbuntu/distro/lib/libxml2.la
#   inflating: ShuTuUbuntu/distro/lib/libstdc++.so.6
#   inflating: ShuTuUbuntu/distro/lib/libQtHelp.so.4
#   inflating: ShuTuUbuntu/distro/lib/libfontconfig.so.1.10.1
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-subset.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_omp.so
#   inflating: ShuTuUbuntu/distro/lib/libcairo-script-interpreter.so.2.11400.6
#   inflating: ShuTuUbuntu/distro/lib/libtiffxx.so
#   inflating: ShuTuUbuntu/distro/lib/libpangoft2-1.0.la
#   inflating: ShuTuUbuntu/distro/lib/libgraphite2.so.3.0.1
#   inflating: ShuTuUbuntu/distro/lib/libfftw3.a
#   inflating: ShuTuUbuntu/distro/lib/libhdf5hl_fortran.la
#   inflating: ShuTuUbuntu/distro/lib/libtiffxx.so.5
#   inflating: ShuTuUbuntu/distro/lib/libQtSvg.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libgomp.so.1
#   inflating: ShuTuUbuntu/distro/lib/libgettextlib.so
#   inflating: ShuTuUbuntu/distro/lib/libffi.so.6.0.4
#   inflating: ShuTuUbuntu/distro/lib/libpcrecpp.a
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_omp.so.3
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl_cpp.so
#   inflating: ShuTuUbuntu/distro/lib/libz.so.1
#   inflating: ShuTuUbuntu/distro/lib/libicutu.so.58.2
#    creating: ShuTuUbuntu/distro/lib/cairo/
#   inflating: ShuTuUbuntu/distro/lib/cairo/libcairo-trace.so.0
#   inflating: ShuTuUbuntu/distro/lib/cairo/libcairo-trace.so
#   inflating: ShuTuUbuntu/distro/lib/cairo/libcairo-trace.la
#   inflating: ShuTuUbuntu/distro/lib/cairo/libcairo-trace.a
#   inflating: ShuTuUbuntu/distro/lib/cairo/libcairo-trace.so.0.0.0
#   inflating: ShuTuUbuntu/distro/lib/libQtCLucene.so.4
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz.la
#   inflating: ShuTuUbuntu/distro/lib/libcairo-gobject.so
#   inflating: ShuTuUbuntu/distro/lib/libasan.so.5
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-gobject.so.0
#   inflating: ShuTuUbuntu/distro/lib/libpango-1.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libQtCore.prl
#   inflating: ShuTuUbuntu/distro/lib/libpango-1.0.so.0.4000.4
#   inflating: ShuTuUbuntu/distro/lib/libpixman-1.so.0.34.0
#   inflating: ShuTuUbuntu/distro/lib/libcairo.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_omp.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libgettextpo.a
#   inflating: ShuTuUbuntu/distro/lib/libtiff.so.5
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_threads.so
#   inflating: ShuTuUbuntu/distro/lib/libgettextlib-0.19.8.1.so
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-icu.so.0.10400.3
#   inflating: ShuTuUbuntu/distro/lib/libitm.so.1.0.0
#   inflating: ShuTuUbuntu/distro/lib/libpng16.so.16.34.0
#   inflating: ShuTuUbuntu/distro/lib/libcairo.so.2.11400.10
#   inflating: ShuTuUbuntu/distro/lib/libffi.so.6
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl.a
#   inflating: ShuTuUbuntu/distro/lib/libhdf5.so.10
#   inflating: ShuTuUbuntu/distro/lib/libgio-2.0.so.0.5500.0
#   inflating: ShuTuUbuntu/distro/lib/libicudata.so.58.2
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-subset.so.0
#   inflating: ShuTuUbuntu/distro/lib/libicuuc.so
#   inflating: ShuTuUbuntu/distro/lib/liblzma.la
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_threads.so.3
#   inflating: ShuTuUbuntu/distro/lib/libQtXml.so.4
#   inflating: ShuTuUbuntu/distro/lib/libxml2.so.2.9.8
#   inflating: ShuTuUbuntu/distro/lib/libQtCLucene.la
#   inflating: ShuTuUbuntu/distro/lib/libpangoft2-1.0.so.0.4000.4
#   inflating: ShuTuUbuntu/distro/lib/libQtScript.so.4
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l.so.3
#   inflating: ShuTuUbuntu/distro/lib/libQtNetwork.so.4
#    creating: ShuTuUbuntu/distro/lib/engines/
#   inflating: ShuTuUbuntu/distro/lib/engines/libgmp.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libcapi.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libpadlock.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libubsec.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libchil.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libcswift.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libnuron.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libsureware.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libaep.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libgost.so
#   inflating: ShuTuUbuntu/distro/lib/engines/libatalla.so
#   inflating: ShuTuUbuntu/distro/lib/engines/lib4758cca.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l.so.3.5.7
#   inflating: ShuTuUbuntu/distro/lib/libQtGui.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libQtWebKit.so.4.9
#   inflating: ShuTuUbuntu/distro/lib/libgthread-2.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libitm.so.1
#   inflating: ShuTuUbuntu/distro/lib/libfontconfig.la
#   inflating: ShuTuUbuntu/distro/lib/libcairo-gobject.la
#   inflating: ShuTuUbuntu/distro/lib/libQtXmlPatterns.la
#   inflating: ShuTuUbuntu/distro/lib/libpng16.so.16
#   inflating: ShuTuUbuntu/distro/lib/libpng16.a
#   inflating: ShuTuUbuntu/distro/lib/libQtDBus.la
#   inflating: ShuTuUbuntu/distro/lib/libtsan.so
#   inflating: ShuTuUbuntu/distro/lib/libubsan.so.1.0.0
#   inflating: ShuTuUbuntu/distro/lib/libatomic.so
#   inflating: ShuTuUbuntu/distro/lib/libQtSql.so
#   inflating: ShuTuUbuntu/distro/lib/liblsan.so
#   inflating: ShuTuUbuntu/distro/lib/libQtWebKit.la
#   inflating: ShuTuUbuntu/distro/lib/libgthread-2.0.so
#   inflating: ShuTuUbuntu/distro/lib/libQtDesigner.so
#   inflating: ShuTuUbuntu/distro/lib/libhdf5.so.10.3.1
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_threads.a
#   inflating: ShuTuUbuntu/distro/lib/libhdf5hl_fortran.so.10
#   inflating: ShuTuUbuntu/distro/lib/libicudata.a
#   inflating: ShuTuUbuntu/distro/lib/libcairo-script-interpreter.a
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-icu.a
#   inflating: ShuTuUbuntu/distro/lib/libjansson.so.4.7.0
#   inflating: ShuTuUbuntu/distro/lib/libgio-2.0.la
#   inflating: ShuTuUbuntu/distro/lib/libQtDeclarative.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libfftw3.so.3
#   inflating: ShuTuUbuntu/distro/lib/libjpeg.so.9
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libQtNetwork.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/liblsan.so.0.0.0
#   inflating: ShuTuUbuntu/distro/lib/libpixman-1.so
#   inflating: ShuTuUbuntu/distro/lib/libglib-2.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libz.so.1.2.11
#   inflating: ShuTuUbuntu/distro/lib/libjansson.so.4
#   inflating: ShuTuUbuntu/distro/lib/libssl.so.1.0.0
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-icu.so.0.10706.0
#   inflating: ShuTuUbuntu/distro/lib/libfftw3.la
#   inflating: ShuTuUbuntu/distro/lib/libQtScriptTools.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libcharset.a
#   inflating: ShuTuUbuntu/distro/lib/liblzma.so.5.2.4
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz.a
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_cpp.so.15.0.0
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_fortran.la
#   inflating: ShuTuUbuntu/distro/lib/libgettextpo.so.0
#   inflating: ShuTuUbuntu/distro/lib/libfftw3.so
#   inflating: ShuTuUbuntu/distro/lib/libgmodule-2.0.la
#   inflating: ShuTuUbuntu/distro/lib/libcharset.so
#   inflating: ShuTuUbuntu/distro/lib/libpcreposix.so.0.0.5
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-subset.so.0.10706.0
#   inflating: ShuTuUbuntu/distro/lib/libcairo.a
#   inflating: ShuTuUbuntu/distro/lib/libQtDesigner.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libQtScript.so
#   inflating: ShuTuUbuntu/distro/lib/libglib-2.0.so.0.5104.0
#   inflating: ShuTuUbuntu/distro/lib/libfreetype.so.6
#   inflating: ShuTuUbuntu/distro/lib/libcairo-gobject.so.2.11400.10
#   inflating: ShuTuUbuntu/distro/lib/libgmodule-2.0.so
#   inflating: ShuTuUbuntu/distro/lib/libjansson.so
#   inflating: ShuTuUbuntu/distro/lib/libQtXml.la
#   inflating: ShuTuUbuntu/distro/lib/libtiffxx.a
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl_cpp.la
#   inflating: ShuTuUbuntu/distro/lib/libpangocairo-1.0.so.0.4000.4
#   inflating: ShuTuUbuntu/distro/lib/libQtTest.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libQtWebKit.so.4.9.4
#   inflating: ShuTuUbuntu/distro/lib/libicuio.a
#   inflating: ShuTuUbuntu/distro/lib/libiconv.so
#   inflating: ShuTuUbuntu/distro/lib/libgomp.so
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz.so.0.10400.3
#   inflating: ShuTuUbuntu/distro/lib/libgomp.so.1.0.0
#   inflating: ShuTuUbuntu/distro/lib/libiconv.so.2.6.0
#   inflating: ShuTuUbuntu/distro/lib/libpcre.la
#   inflating: ShuTuUbuntu/distro/lib/libQtCLucene.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libQtHelp.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libicui18n.so
#   inflating: ShuTuUbuntu/distro/lib/libpcre.a
#   inflating: ShuTuUbuntu/distro/lib/libQtDesigner.so.4
#   inflating: ShuTuUbuntu/distro/lib/libglib-2.0.la
#   inflating: ShuTuUbuntu/distro/lib/libQtWebKit.prl
#   inflating: ShuTuUbuntu/distro/lib/libpangoft2-1.0.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_threads.so.3
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_cpp.so
#   inflating: ShuTuUbuntu/distro/lib/libpangocairo-1.0.so.0.4000.14
#   inflating: ShuTuUbuntu/distro/lib/libgettextpo.so.0.5.4
#   inflating: ShuTuUbuntu/distro/lib/libQtDBus.so.4
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f.so
#   inflating: ShuTuUbuntu/distro/lib/libcharset.la
#   inflating: ShuTuUbuntu/distro/lib/libgobject-2.0.so
#   inflating: ShuTuUbuntu/distro/lib/libjansson.a
#   inflating: ShuTuUbuntu/distro/lib/libasan.so
#   inflating: ShuTuUbuntu/distro/lib/libQtScript.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libicudata.so
#   inflating: ShuTuUbuntu/distro/lib/libhdf5hl_fortran.so
#   inflating: ShuTuUbuntu/distro/lib/libpng.a
#   inflating: ShuTuUbuntu/distro/lib/libitm.so
#   inflating: ShuTuUbuntu/distro/lib/libgettextlib.la
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_cpp.a
#   inflating: ShuTuUbuntu/distro/lib/libQtDesignerComponents.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libgcc_s.so
#   inflating: ShuTuUbuntu/distro/lib/libffi.so
#   inflating: ShuTuUbuntu/distro/lib/libtiff.so
#   inflating: ShuTuUbuntu/distro/lib/libQtScriptTools.prl
#   inflating: ShuTuUbuntu/distro/lib/libasprintf.la
#   inflating: ShuTuUbuntu/distro/lib/libQtDeclarative.so.4
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_fortran.so.10.0.5
#   inflating: ShuTuUbuntu/distro/lib/libQtXmlPatterns.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libfftw3.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libQtSvg.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libhdf5hl_fortran.so.10.0.4
#   inflating: ShuTuUbuntu/distro/lib/liblzma.so.5
#   inflating: ShuTuUbuntu/distro/lib/libpcre.so
#   inflating: ShuTuUbuntu/distro/lib/libQtSql.so.4
#   inflating: ShuTuUbuntu/distro/lib/libatomic.so.1.2.0
#   inflating: ShuTuUbuntu/distro/lib/libgthread-2.0.so.0.5104.0
#   inflating: ShuTuUbuntu/distro/lib/libgraphite2.so
#   inflating: ShuTuUbuntu/distro/lib/charset.alias
#   inflating: ShuTuUbuntu/distro/lib/libquadmath.so.0.0.0
#   inflating: ShuTuUbuntu/distro/lib/preloadable_libintl.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_threads.so
#   inflating: ShuTuUbuntu/distro/lib/libQtHelp.so
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl.la
#   inflating: ShuTuUbuntu/distro/lib/libfontconfig.so
#   inflating: ShuTuUbuntu/distro/lib/liblsan.so.0
#   inflating: ShuTuUbuntu/distro/lib/libgettextsrc-0.19.8.1.so
#    creating: ShuTuUbuntu/distro/lib/cmake/
#    creating: ShuTuUbuntu/distro/lib/cmake/libxml2/
#   inflating: ShuTuUbuntu/distro/lib/cmake/libxml2/libxml2-config.cmake
#    creating: ShuTuUbuntu/distro/lib/cmake/harfbuzz/
#   inflating: ShuTuUbuntu/distro/lib/cmake/harfbuzz/harfbuzz-config.cmake
#    creating: ShuTuUbuntu/distro/lib/cmake/fftw3/
#   inflating: ShuTuUbuntu/distro/lib/cmake/fftw3/FFTW3fConfig.cmake
#   inflating: ShuTuUbuntu/distro/lib/cmake/fftw3/FFTW3Config.cmake
#   inflating: ShuTuUbuntu/distro/lib/cmake/fftw3/FFTW3fConfigVersion.cmake
#   inflating: ShuTuUbuntu/distro/lib/cmake/fftw3/FFTW3lConfigVersion.cmake
#   inflating: ShuTuUbuntu/distro/lib/cmake/fftw3/FFTW3ConfigVersion.cmake
#   inflating: ShuTuUbuntu/distro/lib/cmake/fftw3/FFTW3lConfig.cmake
#   inflating: ShuTuUbuntu/distro/lib/libQtXml.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3.so.3.5.7
#   inflating: ShuTuUbuntu/distro/lib/libgobject-2.0.so.0.5104.0
#   inflating: ShuTuUbuntu/distro/lib/libgettextsrc.la
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_omp.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libfreetype.so.6.12.6
#   inflating: ShuTuUbuntu/distro/lib/libicuuc.so.58.2
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_threads.a
#   inflating: ShuTuUbuntu/distro/lib/libffi.la
#   inflating: ShuTuUbuntu/distro/lib/libQtCLucene.so
#   inflating: ShuTuUbuntu/distro/lib/libcrypto.a
#   inflating: ShuTuUbuntu/distro/lib/libicuuc.a
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-gobject.so.0.10706.0
#   inflating: ShuTuUbuntu/distro/lib/libQtXmlPatterns.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libasprintf.so
#    creating: ShuTuUbuntu/distro/lib/glib-2.0/
#    creating: ShuTuUbuntu/distro/lib/glib-2.0/include/
#   inflating: ShuTuUbuntu/distro/lib/glib-2.0/include/glibconfig.h
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_fortran.so.10
#   inflating: ShuTuUbuntu/distro/lib/libQtCLucene.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/liblzma.so
#   inflating: ShuTuUbuntu/distro/lib/libtiffxx.so.5.4.0
#   inflating: ShuTuUbuntu/distro/lib/libgobject-2.0.so.0.5500.0
#   inflating: ShuTuUbuntu/distro/lib/libicuio.so
#   inflating: ShuTuUbuntu/distro/lib/libpcrecpp.la
#   inflating: ShuTuUbuntu/distro/lib/libgraphite2.so.3
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_threads.so.3.5.7
#   inflating: ShuTuUbuntu/distro/lib/libgthread-2.0.so.0.5500.0
#   inflating: ShuTuUbuntu/distro/lib/libcairo-script-interpreter.so.2.11400.10
#   inflating: ShuTuUbuntu/distro/lib/libQtMultimedia.so
#   inflating: ShuTuUbuntu/distro/lib/libgettextsrc.so
#   inflating: ShuTuUbuntu/distro/lib/libQtDBus.prl
#   inflating: ShuTuUbuntu/distro/lib/libasan.so.5.0.0
#   inflating: ShuTuUbuntu/distro/lib/libQtOpenGL.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl_cpp.so.11
#   inflating: ShuTuUbuntu/distro/lib/libcrypto.so.1.0.0
#   inflating: ShuTuUbuntu/distro/lib/libQtTest.la
#   inflating: ShuTuUbuntu/distro/lib/libpcrecpp.so
#   inflating: ShuTuUbuntu/distro/lib/libQtOpenGL.so
#   inflating: ShuTuUbuntu/distro/lib/libQtGui.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libhdf5.settings
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-icu.la
#   inflating: ShuTuUbuntu/distro/lib/libhdf5.so
#   inflating: ShuTuUbuntu/distro/lib/libpcrecpp.so.0
#   inflating: ShuTuUbuntu/distro/lib/libQtTest.prl
#   inflating: ShuTuUbuntu/distro/lib/libatomic.so.1
#   inflating: ShuTuUbuntu/distro/lib/libQtDeclarative.la
#   inflating: ShuTuUbuntu/distro/lib/libQtGui.la
#   inflating: ShuTuUbuntu/distro/lib/libiconv.a
#   inflating: ShuTuUbuntu/distro/lib/libQtXmlPatterns.so.4
#   inflating: ShuTuUbuntu/distro/lib/libQtScriptTools.so.4
#   inflating: ShuTuUbuntu/distro/lib/libQtCLucene.prl
#   inflating: ShuTuUbuntu/distro/lib/libtsan.so.0.0.0
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-gobject.la
#   inflating: ShuTuUbuntu/distro/lib/libssl.a
#   inflating: ShuTuUbuntu/distro/lib/libQtNetwork.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_threads.a
#   inflating: ShuTuUbuntu/distro/lib/libicutest.a
#   inflating: ShuTuUbuntu/distro/lib/libjpeg.so.9.3.0
#   inflating: ShuTuUbuntu/distro/lib/libQtGui.so
#   inflating: ShuTuUbuntu/distro/lib/libQtOpenGL.prl
#   inflating: ShuTuUbuntu/distro/lib/libcairo-gobject.so.2.11400.6
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_cpp.so.15
#   inflating: ShuTuUbuntu/distro/lib/libcairo-gobject.so.2
#   inflating: ShuTuUbuntu/distro/lib/liblzma.so.5.2.3
#   inflating: ShuTuUbuntu/distro/lib/libfreetype.la
#   inflating: ShuTuUbuntu/distro/lib/libubsan.so
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_fortran.so
#   inflating: ShuTuUbuntu/distro/lib/libtiff.so.5.4.0
#   inflating: ShuTuUbuntu/distro/lib/libcairo-script-interpreter.la
#   inflating: ShuTuUbuntu/distro/lib/libcairo-script-interpreter.so.2
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_threads.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libtsan.so.0
#   inflating: ShuTuUbuntu/distro/lib/libjpeg.so
#   inflating: ShuTuUbuntu/distro/lib/libxml2.so.2
#   inflating: ShuTuUbuntu/distro/lib/libpangoft2-1.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl_cpp.so.11.1.1
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl.so.10
#   inflating: ShuTuUbuntu/distro/lib/libQtCore.so.4
#   inflating: ShuTuUbuntu/distro/lib/libhdf5hl_fortran.a
#   inflating: ShuTuUbuntu/distro/lib/libquadmath.so.0
#   inflating: ShuTuUbuntu/distro/lib/libpng.so
#   inflating: ShuTuUbuntu/distro/lib/libfreetype.so.6.15.0
#   inflating: ShuTuUbuntu/distro/lib/libcairo-gobject.a
#   inflating: ShuTuUbuntu/distro/lib/libQtSql.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libcairo.so.2.11400.6
#   inflating: ShuTuUbuntu/distro/lib/libgio-2.0.so
#   inflating: ShuTuUbuntu/distro/lib/libicuuc.so.58
#   inflating: ShuTuUbuntu/distro/lib/libQtWebKit.so.4
#   inflating: ShuTuUbuntu/distro/lib/libQtDesignerComponents.prl
#   inflating: ShuTuUbuntu/distro/lib/libQtScriptTools.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libglib-2.0.so.0.5500.0
#   inflating: ShuTuUbuntu/distro/lib/libQtXmlPatterns.prl
#   inflating: ShuTuUbuntu/distro/lib/libpcreposix.a
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l.a
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_fortran.a
#   inflating: ShuTuUbuntu/distro/lib/libz.so
#    creating: ShuTuUbuntu/distro/lib/icu/
#    creating: ShuTuUbuntu/distro/lib/icu/current/
#   inflating: ShuTuUbuntu/distro/lib/icu/current/Makefile.inc
#   inflating: ShuTuUbuntu/distro/lib/icu/current/pkgdata.inc
#   inflating: ShuTuUbuntu/distro/lib/icu/Makefile.inc
#   inflating: ShuTuUbuntu/distro/lib/icu/pkgdata.inc
#    creating: ShuTuUbuntu/distro/lib/icu/58.2/
#   inflating: ShuTuUbuntu/distro/lib/icu/58.2/Makefile.inc
#   inflating: ShuTuUbuntu/distro/lib/icu/58.2/pkgdata.inc
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_omp.so
#   inflating: ShuTuUbuntu/distro/lib/libQtDeclarative.so
#   inflating: ShuTuUbuntu/distro/lib/libgmodule-2.0.so.0.5500.0
#   inflating: ShuTuUbuntu/distro/lib/libfontconfig.so.1
#   inflating: ShuTuUbuntu/distro/lib/libpixman-1.so.0
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l_threads.so.3
#   inflating: ShuTuUbuntu/distro/lib/libfreetype.a
#   inflating: ShuTuUbuntu/distro/lib/libtiff.a
#   inflating: ShuTuUbuntu/distro/lib/libasprintf.a
#   inflating: ShuTuUbuntu/distro/lib/libssl.so
#   inflating: ShuTuUbuntu/distro/lib/libpangoft2-1.0.so.0.4000.14
#   inflating: ShuTuUbuntu/distro/lib/libcairo.so.2
#   inflating: ShuTuUbuntu/distro/lib/libicutu.so.58
#   inflating: ShuTuUbuntu/distro/lib/libQtXml.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libQtDBus.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz.so
#   inflating: ShuTuUbuntu/distro/lib/libpcreposix.so
#   inflating: ShuTuUbuntu/distro/lib/libQtScript.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-icu.so.0
#   inflating: ShuTuUbuntu/distro/lib/libQtSql.la
#   inflating: ShuTuUbuntu/distro/lib/libQtScriptTools.la
#   inflating: ShuTuUbuntu/distro/lib/libpng16.so.16.36.0
#   inflating: ShuTuUbuntu/distro/lib/libQtOpenGL.la
#   inflating: ShuTuUbuntu/distro/lib/libQtCore.la
#   inflating: ShuTuUbuntu/distro/lib/libQtSvg.so.4
#    creating: ShuTuUbuntu/distro/lib/gettext/
#   inflating: ShuTuUbuntu/distro/lib/gettext/urlget
#   inflating: ShuTuUbuntu/distro/lib/gettext/user-email
#   inflating: ShuTuUbuntu/distro/lib/gettext/project-id
#   inflating: ShuTuUbuntu/distro/lib/gettext/hostname
#   inflating: ShuTuUbuntu/distro/lib/gettext/cldr-plurals
#   inflating: ShuTuUbuntu/distro/lib/libpangocairo-1.0.so.0
#   inflating: ShuTuUbuntu/distro/lib/libgthread-2.0.la
#   inflating: ShuTuUbuntu/distro/lib/libpcrecpp.so.0.0.1
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-subset.a
#   inflating: ShuTuUbuntu/distro/lib/libQtHelp.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libQtCore.so
#   inflating: ShuTuUbuntu/distro/lib/libQtScriptTools.so
#   inflating: ShuTuUbuntu/distro/lib/libpcreposix.so.0
#   inflating: ShuTuUbuntu/distro/lib/libQtDeclarative.prl
#   inflating: ShuTuUbuntu/distro/lib/libiconv.so.2
#   inflating: ShuTuUbuntu/distro/lib/libfftw3_threads.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz-gobject.a
#   inflating: ShuTuUbuntu/distro/lib/libpango-1.0.so.0.4000.14
#   inflating: ShuTuUbuntu/distro/lib/libjansson.la
#   inflating: ShuTuUbuntu/distro/lib/libpango-1.0.so
#   inflating: ShuTuUbuntu/distro/lib/libfontconfig.a
#   inflating: ShuTuUbuntu/distro/lib/libcrypto.so
#   inflating: ShuTuUbuntu/distro/lib/libQtXmlPatterns.so
#   inflating: ShuTuUbuntu/distro/lib/libQtSvg.la
#   inflating: ShuTuUbuntu/distro/lib/libQtXml.prl
#   inflating: ShuTuUbuntu/distro/lib/libharfbuzz.so.0.10706.0
#   inflating: ShuTuUbuntu/distro/lib/libgfortran.so.3
#   inflating: ShuTuUbuntu/distro/lib/libhdf5_hl.so.10.2.1
#   inflating: ShuTuUbuntu/distro/lib/libpng.la
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f_threads.so.3.5.8
#   inflating: ShuTuUbuntu/distro/lib/libQtWebKit.so
#   inflating: ShuTuUbuntu/distro/lib/libicutest.so.58.2
#   inflating: ShuTuUbuntu/distro/lib/libQtDBus.so.4.8
#   inflating: ShuTuUbuntu/distro/lib/libQtDesignerComponents.so.4.8.7
#   inflating: ShuTuUbuntu/distro/lib/libasprintf.so.0.0.0
#   inflating: ShuTuUbuntu/distro/lib/libicutu.so
#   inflating: ShuTuUbuntu/distro/lib/libiconv.la
#   inflating: ShuTuUbuntu/distro/lib/libQtNetwork.la
#   inflating: ShuTuUbuntu/distro/lib/libQtUiTools.a
#   inflating: ShuTuUbuntu/distro/lib/libQtDBus.so
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l.la
#   inflating: ShuTuUbuntu/distro/lib/libQtGui.so.4
#   inflating: ShuTuUbuntu/distro/lib/libfftw3l.so
#   inflating: ShuTuUbuntu/distro/lib/libgcc_s.so.1
#   inflating: ShuTuUbuntu/distro/lib/libpcre.so.1.2.9
#   inflating: ShuTuUbuntu/distro/lib/libQtUiTools.prl
#   inflating: ShuTuUbuntu/distro/lib/libgmodule-2.0.so.0.5104.0
#   inflating: ShuTuUbuntu/distro/lib/libfftw3f.so.3
#    creating: ShuTuUbuntu/distro/lib/girepository-1.0/
#   inflating: ShuTuUbuntu/distro/lib/girepository-1.0/PangoFT2-1.0.typelib
#   inflating: ShuTuUbuntu/distro/lib/girepository-1.0/PangoCairo-1.0.typelib
#   inflating: ShuTuUbuntu/distro/lib/girepository-1.0/Pango-1.0.typelib
#   inflating: ShuTuUbuntu/distro/lib/girepository-1.0/HarfBuzz-0.0.typelib
#   inflating: ShuTuUbuntu/distro/~.autosave.swc
#   inflating: ShuTuUbuntu/distro/~20-22-1-10.autosave.swc
#    creating: ShuTuUbuntu/distro/bin/
#   inflating: ShuTuUbuntu/distro/bin/config.xml
#    creating: ShuTuUbuntu/distro/bin/doc/
#   inflating: ShuTuUbuntu/distro/bin/doc/index.html
#   inflating: ShuTuUbuntu/distro/bin/doc/flyem_proofread_help.html
#   inflating: ShuTuUbuntu/distro/bin/doc/ThirdPartyLibraries.txt
#   inflating: ShuTuUbuntu/distro/bin/doc/menu.html
#   inflating: ShuTuUbuntu/distro/bin/doc/shortcut.html
#   inflating: ShuTuUbuntu/distro/bin/doc/shortcut_3d.html
#   inflating: ShuTuUbuntu/distro/bin/ShuTu
#   inflating: ShuTuUbuntu/ShuTuAutoTraceOneStack.c
#   inflating: ShuTuUbuntu/analyzeSWC.py

# %%
# Now there should be one new directory: ShuTuUbuntu/
# !ls
# Out:
# sample_data  ShuTuUbuntu  wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip

# %% [markdown]
# # Building
#
# Now some heavy building, which only needs to be done once every 12 hours, when Colab tears down the VM and throws everything away (except this notebook file itself).

# %%
# %%shell
# set -m # needed to avoid error: bash: no job control in this shell
# cd ShuTuUbuntu
# ./build.sh
# Out:
# gcc  -o generator generator.c
# ./generator <cdf.p >cdf.c
# gcc -c  -fPIC cdf.c
# ./generator <fct.min.p >fct.min.c
# gcc -c  -fPIC fct.min.c
# ./generator <filters.p >filters.c
# gcc -c  -fPIC filters.c
# ./generator <linear.algebra.p >linear.algebra.c
# gcc -c  -fPIC linear.algebra.c
# ./generator <array.p >array.c
# gcc -c  -fPIC array.c
# ./generator <connectivity.p >connectivity.c
# gcc -c  -fPIC connectivity.c
# ./generator <region.p >region.c
# gcc -c  -fPIC region.c
# ./generator <fct.root.p >fct.root.c
# gcc -c  -fPIC fct.root.c
# ./generator <image.p >image.c
# gcc -c  -fPIC image.c
# ./generator <utilities.p >utilities.c
# gcc -c  -fPIC utilities.c
# ./generator <snake.p >snake.c
# gcc -c  -fPIC snake.c
# ./generator <hash.p >hash.c
# gcc -c  -fPIC hash.c
# ./generator <level.set.p >level.set.c
# gcc -c  -fPIC level.set.c
# ./generator <water.shed.p >water.shed.c
# gcc -c  -fPIC water.shed.c
# ./generator <fft.p >fft.c
# gcc -c  -fPIC fft.c
# ./generator <draw.p >draw.c
# gcc -c  -fPIC draw.c
# ./generator <histogram.p >histogram.c
# gcc -c  -fPIC histogram.c
# ./generator <swc.p >swc.c
# gcc -c  -fPIC swc.c
# ./generator <paths.p >paths.c
# gcc -c  -fPIC paths.c
# ./generator <mylib.p >mylib.c
# gcc -c  -fPIC mylib.c
# ./generator <svg.p >svg.c
# gcc -c  -fPIC svg.c
# cd MY_TIFF   && make && cd ..
# make[1]: Entering directory '/content/ShuTuUbuntu/mylib/MY_TIFF'
# gcc  -o generator generator.c
# ./generator <tiff.io.p >tiff.io.c
# gcc -c  -fPIC tiff.io.c
# ./generator <tiff.image.p >tiff.image.c
# gcc -c  -fPIC tiff.image.c
# ld -r -o mytiff.o tiff.io.o tiff.image.o
# ./generator <utilities.p >utilities.c
# gcc -c  -fPIC utilities.c
# gcc  -fPIC -o tiffconvert app.convert.c utilities.o mytiff.o
# gcc  -fPIC -o tifftagger app.tagger.c utilities.o mytiff.o
# gcc  -fPIC -o tiffRGB app.color.c utilities.o mytiff.o
# gcc  -fPIC -o tiffshow app.show.c utilities.o mytiff.o
# gcc  -fPIC -o mrc2tiff app.mrc2.c utilities.o mytiff.o
# make[1]: Leaving directory '/content/ShuTuUbuntu/mylib/MY_TIFF'
# cd MY_FFT    && make && cd ..
# make[1]: Entering directory '/content/ShuTuUbuntu/mylib/MY_FFT'
# gcc -c  -fPIC fft.F.c
# gcc -c  -fPIC fft.D.c
# gcc -c  -fPIC myfft.c
# make[1]: Leaving directory '/content/ShuTuUbuntu/mylib/MY_FFT'
# ar cr libmylib.a cdf.o fct.min.o filters.o linear.algebra.o array.o connectivity.o region.o fct.root.o image.o utilities.o snake.o  hash.o level.set.o water.shed.o fft.o draw.o histogram.o swc.o paths.o mylib.o svg.o MY_FFT/myfft.o MY_TIFF/mytiff.o
# ranlib libmylib.a
# gcc -fPIC -c libShuTu.c -Imylib
# gcc -shared -o libShuTu.so libShuTu.o -Lmylib -lmylib -lm
# gcc -fPIC -c ShuTuAutoTraceOneStack.c -Imylib
# gcc -o ShuTuAutoTraceOneStack ShuTuAutoTraceOneStack.o libShuTu.o -Lmylib -lmylib -lm
# mpicc -fPIC -c ShuTuAutoTrace.c -Imylib
# mpicc  -o ShuTuAutoTrace ShuTuAutoTrace.o libShuTu.o -Lmylib -lmylib -lm
# mpicc -fPIC -c createTiffStacksZeiss.c -Imylib
# mpicc -o createTiffStacksZeiss createTiffStacksZeiss.o libShuTu.o -Lmylib -lmylib -lm
# mpicc -fPIC -c processImages.c -Imylib
# mpicc -o processImages processImages.o libShuTu.o -Lmylib -lmylib -lm
# mpicc -fPIC -c stitchTiles.c -Imylib
# mpicc -o stitchTiles stitchTiles.o libShuTu.o -Lmylib -lmylib -lm
# mpicc -fPIC -c scaleSWC.c -Imylib
# mpicc -o scaleSWC scaleSWC.o libShuTu.o -Lmylib -lmylib -lm
# bash: cannot set terminal process group (118): Inappropriate ioctl for device
# bash: no job control in this shell
# root@55ff33362eac:/content/ShuTuUbuntu#

# %% [markdown]
# # Debugging
#
# For the record, build.sh crapped out at:
# ```
# make[1]: Leaving directory '/content/ShuTuUbuntu/mylib/MY_FFT'
# ar cr libmylib.a cdf.o fct.min.o filters.o linear.algebra.o array.o connectivity.o region.o fct.root.o image.o utilities.o snake.o  hash.o level.set.o water.shed.o fft.o draw.o histogram.o swc.o paths.o mylib.o svg.o MY_FFT/myfft.o MY_TIFF/mytiff.o
# ranlib libmylib.a
# make: Nothing to be done for 'all'.
# bash: cannot set terminal process group (626): Inappropriate ioctl for device
# bash: no job control in this shell
# root@23b2ea86b11a:/content/ShuTuUbuntu#
# ```
#
# So, an error message occurred. But it doesn't seem to actually cause any real problems. I.e. the "bash: cannot set terminal process group" error message can be ignored.

# %% [markdown]
# While running, build.sh errored but nonetheless it did seem to complete it's last task: write out the process.sh file. The file even has the correct permissions as set with _chmod_ which is the penultimate command. (Also as will become clear later, the process.sh file isn't even used during this notebook.)

# %%
# Debugging. What's in that build.sh file that is causing error messages?
# !cat ShuTuUbuntu/build.sh
# Out:
# #!/bin/bash
#
# set -e
#
# if ! [ -x "$(command -v mpicc)" ]
# then
#   echo "Cannot find mpicc. Installing openmpi ..."
#   if [ ! -d Downloads ]
#   then
#     mkdir Downloads
#   fi
#   cd Downloads
#   downloadDir=$PWD
#   MPI_RUN=$downloadDir/local/bin/mpirun
#   if [ ! -f $MPI_RUN ]
#   then
#     if [ ! -d $downloadDir/openmpi-4.0.1 ]
#     then
#       package=openmpi-4.0.1.tar.gz
#       host=https://download.open-mpi.org/release/open-mpi/v4.0
#       if [ -x "$(command -v wget)" ]
#       then
#         wget $host/$package
#       else
#         if [ -x "$(command -v curl)" ]
#         then
#           curl -c - -O $host/$package
#         else
#           echo 'Failed to get $package: No download tool found.'
#           exit 1
#         fi
#       fi
#       gunzip -c $package | tar xf -
#       cd openmpi-4.0.1
#       ./configure --prefix=$downloadDir/local --disable-mpi-fortran
#       make all install
#       cd ..
#     fi
#     echo "export PATH=$downloadDir/local/bin:\$PATH" >> ~/.bashrc
#   fi
#   cd ..
# else
#   MPI_RUN=mpirun
# fi
#
# export PATH=$downloadDir/local/bin:$PATH
# cd mylib
# make
# cd ..
# make
#
# echo '#!/bin/bash' > process.sh
# echo 'set -e' >> process.sh
# echo 'if [ $# -lt 4 ]; then' >> process.sh
# echo '  echo "Usage: ./process.sh <data_dir> <common_name> <param_file> <num_proc>"' >> process.sh
# echo '  exit 1' >> process.sh
# echo 'fi' >> process.sh
# echo 'dataDir=$1' >> process.sh
# echo 'commonName=$2' >> process.sh
# echo 'paramFile=$3' >> process.sh
# echo 'numproc=$4' >> process.sh
# echo ${MPI_RUN}' -n $numproc ./createTiffStacksZeiss $dataDir $commonName' >> process.sh
# echo ${MPI_RUN}' -n $numproc ./processImages $dataDir' >> process.sh
# echo ${MPI_RUN}' -n $numproc ./stitchTiles $dataDir' >> process.sh
# echo ${MPI_RUN}' -n $numproc ./ShuTuAutoTrace $dataDir $paramFile' >> process.sh
#
# chmod u+x process.sh
# bash

# %%
# !pwd
# !ls -l ShuTuUbuntu/process.sh
# !cat ShuTuUbuntu/process.sh

# %% [markdown]
# ## Continuing onward
#
# Ignoring the (harmless?) error messages from build.sh, the next stage in the ShuTu tutorial is described in section, ["Image processing and automated reconstruction"](http://personal.psu.edu/dzj2/ShuTu/):
#
# >Download the image files from [Granule Cell 63X Start](https://psu.box.com/shared/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip). Unzip in the home directory, which should create a directory granuleCell63XStart.
#
# Specifically, the link behind "Granule Cell 63X Start" is: [https://psu.box.com/shared/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip](https://psu.box.com/shared/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip)

# %%
# This is a 1.3GB image stack for use in skeletonization (make a SWC file). 
# Downloads in less than 2 minutes
# !wget https://psu.box.com/shared/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# Out:
# --2019-10-12 20:54:27--  https://psu.box.com/shared/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# Resolving psu.box.com (psu.box.com)... 107.152.24.197
# Connecting to psu.box.com (psu.box.com)|107.152.24.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip [following]
# --2019-10-12 20:54:27--  https://psu.box.com/public/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# Reusing existing connection to psu.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://psu.app.box.com/public/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip [following]
# --2019-10-12 20:54:27--  https://psu.app.box.com/public/static/f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# Resolving psu.app.box.com (psu.app.box.com)... 107.152.24.199
# Connecting to psu.app.box.com (psu.app.box.com)|107.152.24.199|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!udl-DnQlJOgz2w7dH7xV6TC18wSEVcXM3XCfKPgXU5nfR7iNJ5aUWjoA249XB2Ktv-OOx-uQQSYC262QW03ACDka8Z-QyzoFQL9xeiRjd2XbZpTtxp32FokQMVFfTdo7CHoSVORRkFA3UYNmuVKHK9ItisKqpbHWSPQsGhMbkhmGa25130eLa9lMIuocdPWmF-ba3dKxOkP9dTx0IiMHDeyW2p2aWNW1PiCfMKgYZCShmj5nN8nyXNKvE-5Ze2B1wR_Ru-wLJ6FrKfmSUwxhmjiC6H2vsUw5mVd9pPYCTycnhAApi86iVNDRxYDIj06U5v117tTnt5H8E-a2FtXkH_ppNi10LfPQ1N-5QbMRpwk9h2tKrzoUqPmXDkt-V-bneYtomGpdbJXXB-ZRCNn9yaOBXlnLp2eiuSitNM02-f6qQMwB1jgbAuIFdP6DGVHnqKHYnAKT8wFOs-xspd_wYoatwmenxHiwHoDjrmGCWjeooKSjkwF9cQ-ELyRKQfYCSPtWAj9CRADFws02X-RCKSxNMeeX7taNix33-P_vBwpjx06R6Ss-70ULrZChuLjEtkc056CqCeqrfq7Aae3q0AAazuZG4AnzZrNp7TtrrzQ6xD7txsKbtQroaTAcRu6GLBo8PFQfQUIePiIuZhpIjYidO7lHlmJsLN7sURjmLz1BepYbIwXNJF_H1KLlT20Zd3TqZZGu115IIBUON-irvsAM-iF9RlNgsuzJruoFEiVW6kbA8LKP6VIJz5jqyZYSvxYoqT0d0wnSC3bMVXA-KBIQycixlvNxFgWv79QCYZ2K3LPn21AcGEwGE3DOdSgHquUh8dkGdo5TcLqGfOdqTeXR4MG70tnJH_9vVtRzBheoKxbgtWtaRdoLcCPi0fIXaivJYWF4-GAlg3-FF9v2kjw1tI9n359-1B4rv_tWy3c01XHmKU0YPWvz6uoF0_eIsJ7iKubHwJGSGSXNNUhJx6bKSXyPsfO0Dh_ZHOPSA77LZt7SL1SAsCk6NmEE20v0rh_z-_e-mb6gNEUaQA_2XWh6qbI9VvwRmw0KV3Wsp7LhtlORo7ZXoBmVjf3WpbOtjJxMogo3FNIoBopjyEwjcFafHMBseUo7tPUI53xn5d5Vn-w61hpVAI_QCg9RcmShDsXKQcZj-JSvjic_RffDUomIpb_9qTI1r3lkSHJr-J_BbCtqTbVtMM-nWBvh7HfwyT_DwJQJooWXXixR-P-Gpb3tcoLGSbVgekx2_2XVpaHNaGH07Yhc08ugNO2XhbyQLmjbC336qJLh_R0oNU3m1VKO22f5nIusoUUSCwSIMUlfgLcqk1hYJ_FopXpIisOwms8bOXayMAepbU4O0WELIZ8TZsG5rHBtVNNYnmtcs6ZyMRHPOWokNG3x1LhLczdI/download [following]
# --2019-10-12 20:54:28--  https://public.boxcloud.com/d/1/b1!udl-DnQlJOgz2w7dH7xV6TC18wSEVcXM3XCfKPgXU5nfR7iNJ5aUWjoA249XB2Ktv-OOx-uQQSYC262QW03ACDka8Z-QyzoFQL9xeiRjd2XbZpTtxp32FokQMVFfTdo7CHoSVORRkFA3UYNmuVKHK9ItisKqpbHWSPQsGhMbkhmGa25130eLa9lMIuocdPWmF-ba3dKxOkP9dTx0IiMHDeyW2p2aWNW1PiCfMKgYZCShmj5nN8nyXNKvE-5Ze2B1wR_Ru-wLJ6FrKfmSUwxhmjiC6H2vsUw5mVd9pPYCTycnhAApi86iVNDRxYDIj06U5v117tTnt5H8E-a2FtXkH_ppNi10LfPQ1N-5QbMRpwk9h2tKrzoUqPmXDkt-V-bneYtomGpdbJXXB-ZRCNn9yaOBXlnLp2eiuSitNM02-f6qQMwB1jgbAuIFdP6DGVHnqKHYnAKT8wFOs-xspd_wYoatwmenxHiwHoDjrmGCWjeooKSjkwF9cQ-ELyRKQfYCSPtWAj9CRADFws02X-RCKSxNMeeX7taNix33-P_vBwpjx06R6Ss-70ULrZChuLjEtkc056CqCeqrfq7Aae3q0AAazuZG4AnzZrNp7TtrrzQ6xD7txsKbtQroaTAcRu6GLBo8PFQfQUIePiIuZhpIjYidO7lHlmJsLN7sURjmLz1BepYbIwXNJF_H1KLlT20Zd3TqZZGu115IIBUON-irvsAM-iF9RlNgsuzJruoFEiVW6kbA8LKP6VIJz5jqyZYSvxYoqT0d0wnSC3bMVXA-KBIQycixlvNxFgWv79QCYZ2K3LPn21AcGEwGE3DOdSgHquUh8dkGdo5TcLqGfOdqTeXR4MG70tnJH_9vVtRzBheoKxbgtWtaRdoLcCPi0fIXaivJYWF4-GAlg3-FF9v2kjw1tI9n359-1B4rv_tWy3c01XHmKU0YPWvz6uoF0_eIsJ7iKubHwJGSGSXNNUhJx6bKSXyPsfO0Dh_ZHOPSA77LZt7SL1SAsCk6NmEE20v0rh_z-_e-mb6gNEUaQA_2XWh6qbI9VvwRmw0KV3Wsp7LhtlORo7ZXoBmVjf3WpbOtjJxMogo3FNIoBopjyEwjcFafHMBseUo7tPUI53xn5d5Vn-w61hpVAI_QCg9RcmShDsXKQcZj-JSvjic_RffDUomIpb_9qTI1r3lkSHJr-J_BbCtqTbVtMM-nWBvh7HfwyT_DwJQJooWXXixR-P-Gpb3tcoLGSbVgekx2_2XVpaHNaGH07Yhc08ugNO2XhbyQLmjbC336qJLh_R0oNU3m1VKO22f5nIusoUUSCwSIMUlfgLcqk1hYJ_FopXpIisOwms8bOXayMAepbU4O0WELIZ8TZsG5rHBtVNNYnmtcs6ZyMRHPOWokNG3x1LhLczdI/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1389488667 (1.3G) [application/zip]
# Saving to: ‘f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip’
#
# f4gs13fs0y9ckrjjo78 100%[===================>]   1.29G  18.2MB/s    in 73s
#
# 2019-10-12 20:55:41 (18.1 MB/s) - ‘f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip’ saved [1389488667/1389488667]

# %%
# !pwd && ls -l
# Out:
# /content
# total 1645644
# -rw-r--r-- 1 root root 1389488667 Oct 12 20:55 f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# drwxr-xr-x 1 root root       4096 Aug 27 16:17 sample_data
# drwxrwxr-x 5 root root       4096 Oct 12 19:14 ShuTuUbuntu
# -rw-r--r-- 1 root root  295628950 Oct 12 19:04 wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip

# %%
# !unzip f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# Out:
# Archive:  f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
#    creating: granuleCell63XStart/
#   inflating: granuleCell63XStart/DG-151213-S1_63X_20percentOverlap_100617_redo_meta.xml
#   inflating: granuleCell63XStart/DG-151213-S1_63X_20percentOverlap_100617_redo_info.xml
#    creating: granuleCell63XStart/slides/
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z103m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z024m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z070m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z121m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z135m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z051m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z071m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z133m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z060m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z014m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z119m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z075m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z073m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z017m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z022m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z081m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z082m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z054m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z017m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z045m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z107m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z008m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z131m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z025m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z112m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z115m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z032m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z064m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z009m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z129m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z015m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z097m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z102m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z118m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z069m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z049m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z031m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z010m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z075m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z106m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z046m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z044m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z114m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z133m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z016m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z049m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z069m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z041m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z044m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z052m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z022m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z128m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z006m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z057m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z089m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z040m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z093m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z091m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z051m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z128m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z124m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z043m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z088m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z041m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z037m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z135m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z063m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z016m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z037m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z066m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z063m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z124m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z119m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z120m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z084m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z090m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z037m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z079m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z020m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z074m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z110m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z026m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z093m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z010m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z026m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z036m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z013m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z072m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z098m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z066m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z098m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z060m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z103m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z062m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z100m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z105m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z128m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z116m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z105m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z038m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z127m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z038m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z011m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z076m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z098m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z056m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z010m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z131m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z099m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z110m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z050m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z007m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z015m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z094m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z059m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z113m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z084m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z070m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z098m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z060m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z090m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z127m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z119m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z109m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z065m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z135m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z023m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z097m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z070m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z094m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z095m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z101m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z047m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z118m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z095m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z121m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z130m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z009m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z016m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z019m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z013m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z096m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z102m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z012m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z055m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z032m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z107m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z132m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z127m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z055m4_ORG.tif
#   inflating: granuleCell63XStart/slides/.DG-151213-S1_63X_20percentOverlap_100617_redo_z028m3.tif.gttDUq
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z053m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z035m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z024m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z048m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z134m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z050m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z033m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z057m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z009m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z129m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z068m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z030m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z017m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z061m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z033m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z012m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z027m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z086m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z007m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z077m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z097m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z100m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z101m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z083m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z103m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z053m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z119m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z134m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z061m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z122m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z070m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z048m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z099m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z090m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z036m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z132m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z059m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z025m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z051m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z133m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z046m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z027m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z029m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z029m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z125m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z081m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z042m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z078m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z092m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z059m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z114m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z105m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z028m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z086m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z018m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z104m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z046m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z100m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z029m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z092m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z016m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z050m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z108m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z076m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z030m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z056m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z114m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z078m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z065m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z042m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z040m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z044m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z033m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z008m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z084m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z095m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z008m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z097m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z015m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z078m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z124m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z028m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z088m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z121m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z053m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z085m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z026m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z112m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z031m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z081m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z077m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z087m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z081m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z111m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z048m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z058m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z020m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z115m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z123m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z111m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z123m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z039m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z051m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z074m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z130m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z112m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z047m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z050m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z076m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z085m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z024m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z085m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z043m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z064m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z117m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z038m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z073m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z128m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z021m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z103m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z089m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z006m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z029m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z102m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z078m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z111m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z037m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z116m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z036m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z067m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z021m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z118m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z108m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z049m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z096m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z134m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z009m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z068m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z130m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z038m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z112m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z100m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z046m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z074m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z040m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z064m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z017m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z061m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z066m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z099m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z008m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z011m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z071m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z099m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z068m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z082m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z096m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z069m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z014m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z057m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z115m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z075m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z110m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z110m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z120m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z094m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z107m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z067m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z007m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z095m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z066m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z006m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z117m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z032m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z058m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z089m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z086m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z120m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z113m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z083m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z063m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z007m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z072m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z021m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z065m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z035m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z076m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z109m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z096m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z123m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z090m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z104m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z080m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z124m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z042m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z020m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z039m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z014m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z047m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z027m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z111m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z094m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z131m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z030m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z015m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z079m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z120m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z129m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z024m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z034m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z052m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z041m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z108m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z082m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z031m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z088m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z075m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z013m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z018m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z040m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z027m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z025m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z019m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z126m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z044m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z117m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z129m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z036m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z080m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z054m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z055m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z123m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z045m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z116m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z023m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z011m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z109m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z107m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z104m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z109m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z125m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z045m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z061m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z087m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z091m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z067m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z030m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z073m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z062m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z059m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z087m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z056m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z068m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z023m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z023m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z018m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z101m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z105m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z063m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z035m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z106m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z093m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z131m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z106m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z028m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z057m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z043m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z074m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z058m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z121m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z114m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z035m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z077m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z125m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z022m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z102m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z104m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z049m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z080m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z064m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z014m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z072m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z052m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z065m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z126m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z011m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z082m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z039m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z126m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z033m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z006m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z073m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z072m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z079m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z054m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z058m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z034m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z047m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z077m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z020m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z048m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z043m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z060m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z013m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z132m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z032m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z091m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z045m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z039m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z118m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z122m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z031m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z113m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z122m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z080m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z028m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z067m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z127m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z071m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z132m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z125m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z092m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z022m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z086m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z116m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z062m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z101m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z012m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z088m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z083m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z010m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z034m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z079m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z025m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z053m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z085m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z056m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z034m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z135m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z042m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z071m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z122m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z087m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z041m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z117m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z021m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z069m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z089m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z062m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z126m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z055m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z018m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z106m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z108m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z130m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z026m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z012m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z054m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z084m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z092m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z019m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z052m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z133m1_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z115m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z091m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z134m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z083m3_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z093m4_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z113m2_ORG.tif
#   inflating: granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_z019m4_ORG.tif

# %% [markdown]
# So, that puts the image stack in directory `/content/granuleCell63XStart/`

# %%
# !pwd && ls -l
# Out:
# /content
# total 1645648
# -rw-r--r-- 1 root root 1389488667 Oct 12 20:55 f4gs13fs0y9ckrjjo78oid7hkv61k2wq.zip
# drwxrwxr-x 3 root root       4096 Oct 26  2017 granuleCell63XStart
# drwxr-xr-x 1 root root       4096 Aug 27 16:17 sample_data
# drwxrwxr-x 5 root root       4096 Oct 12 19:14 ShuTuUbuntu
# -rw-r--r-- 1 root root  295628950 Oct 12 19:04 wszpq3r6hwgoxo8eq0vb1k82fwrabycl.zip

# %%
# How many cores do we have to play with?
# See https://colab.research.google.com/drive/151805XTDg--dgHb3-AXJCpnWaqRhop_2#scrollTo=01i75DIjKA5D


#no.of sockets i.e available slots for physical processors
# !lscpu | grep 'Socket(s):'

#no.of cores each processor is having 
# !lscpu | grep 'Core(s) per socket:'
# Out:
# Socket(s):           1
# Core(s) per socket:  1

# %% [markdown]
# ## Beginning of main action
#
# So far in the story a bunch of code and data ZIP files were downloaded and "installed." Now it's time to start doing things.
#
# At this point, the next step is, quoting the ShuTu tutorial:
# ```
# [1] Create tiff stacks:
# mpirun -n 4 ./createTiffStacksZeiss ~/granuleCell63XStart/ granule
# [here granule is filenameCommon given to the created tiff stacks]
# ```
#
# The example has `-n 4` processors but it seems Colab is giving us 1. Now that we know there is only one core available, the next task is a `mpirun -n 1` where the default invocation would be:
# ```
# mpirun -n 1 ./createTiffStacksZeiss ~/granuleCell63XStart/ granule
# ```
# Wisely, that will cause an error message warning the user to not run as root, but we can ignore that here on Colab. The warning message says to force run-as-root, the trick is to add `-allow-run-as-root`.
#
# So that comes out as the following (I'm also using absolute paths to be more explicit):

# %%
# %%shell
# cd ShuTuUbuntu
#
# mpirun --allow-run-as-root -n 1 ./createTiffStacksZeiss /content/granuleCell63XStart/ granule
# Out:
# Creating tiff stacks from images and xml files in /content/granuleCell63XStart/ with finameCommon=granule
# Number of tasks= 1 My rank= 0 Running on 23b2ea86b11a
# Finding image slices with finames ending with _ORG.tif
# /content/granuleCell63XStart/
# filenameSliceCommon=/content/granuleCell63XStart/slides/DG-151213-S1_63X_20percentOverlap_100617_redo_
# nTiles=4 nz=130 zstart=6 zend=135
# /content/granuleCell63XStart/granule-1.tif
# /content/granuleCell63XStart/granule-2.tif
# /content/granuleCell63XStart/granule-3.tif
# /content/granuleCell63XStart/granule-4.tif

# %% [markdown]
# Next the ShuTu tutorial suggests:
# ```
# [2] Process images:
# mpirun -n 4 processImages ~/granuleCell63XStart/
# ```
# So, tweak that for Colab here and it gets to:

# %%
# %%shell
# cd ShuTuUbuntu
#
# mpirun --allow-run-as-root -n 1 processImages /content/granuleCell63XStart/
# Out:
# Bright field images
# Number of tasks= 1 My rank= 0 Running on 23b2ea86b11a
# ntiff=4 filenameCommon=/content/granuleCell63XStart/granule-
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Save projection to /content/granuleCell63XStart/granule-1.Proj.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Save projection to /content/granuleCell63XStart/granule-4.Proj.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Save projection to /content/granuleCell63XStart/granule-3.Proj.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Save projection to /content/granuleCell63XStart/granule-2.Proj.tif

# %% [markdown]
# Next in the ShuTu tutorial is #3:
# ```
# [3] Stitch images:
# mpirun -n 4 ./stitchTiles ~/granuleCell63XStart/
# ```

# %%
# %%shell
# cd ShuTuUbuntu
# mpirun --allow-run-as-root -n 1 ./stitchTiles /content/granuleCell63XStart/
# Out:
# Number of tasks= 1 My rank= 0 Running on 23b2ea86b11a
# Image dimension=(1040 1388 129) type=0 number of channels=3
# ntiff=4 filenameCommon=/content/granuleCell63XStart/granule-
# Parsing /content/granuleCell63XStart/DG-151213-S1_63X_20percentOverlap_100617_redo_info.xml for tile positions
# numTiles=4 nx=1388 ny=1040 nz=129
# ID=2 X=1112 Y=0
# ID=3 X=1112 Y=833
# ID=4 X=0 Y=833
# ID=1 X=1 Y=0
# Computing offsets between 2 3 offset =75.096153 direction =down
#  Stitching /content/granuleCell63XStart/granule-2.tif and /content/granuleCell63XStart/granule-3.tif. Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Dimensions of overlapping stack nxx=512 nyy=2048 nzz=256. tcmalloc: large alloc 1073741824 bytes == 0x556731ac8000 @  0x7fedff66e1e7 0x5566d4225fa4 0x5566d421e7df 0x7fedfe9bcb97 0x5566d421ccba
# Computing phase correlation. Smoothing planes. Shifts dx=52 dy=-16 dz=0 maxcorr=0.026200. Convert shifts to offsets.
# dx=833 dy=-16 dz=0 maxCorr=0.026200
# Computing offsets between 2 1 offset =75.043228 direction =left
#  Stitching /content/granuleCell63XStart/granule-2.tif and /content/granuleCell63XStart/granule-1.tif. Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Dimensions of overlapping stack nxx=2048 nyy=512 nzz=256. Computing phase correlation. Smoothing planes. Shifts dx=-21 dy=-72 dz=2 maxcorr=0.015550. Convert shifts to offsets.
# dx=-21 dy=-1114 dz=2 maxCorr=0.015550
# Computing offsets between 3 4 offset =75.115273 direction =left
#  Stitching /content/granuleCell63XStart/granule-3.tif and /content/granuleCell63XStart/granule-4.tif. Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Dimensions of overlapping stack nxx=2048 nyy=512 nzz=256. Computing phase correlation. Smoothing planes. Shifts dx=-21 dy=-72 dz=2 maxcorr=0.015873. Convert shifts to offsets.
# dx=-21 dy=-1115 dz=2 maxCorr=0.015873
# Computing offsets between 4 1 offset =75.096153 direction =up
#  Stitching /content/granuleCell63XStart/granule-4.tif and /content/granuleCell63XStart/granule-1.tif. Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Dimensions of overlapping stack nxx=512 nyy=2048 nzz=256. Computing phase correlation. Smoothing planes. Shifts dx=-52 dy=17 dz=0 maxcorr=0.021515. Convert shifts to offsets.
# dx=-833 dy=17 dz=0 maxCorr=0.021515
# Connected 2 3
# Connected 4 1
# Connected 3 4
# connect tiles 2 3
# /content/granuleCell63XStart/stitchRes.2.3.txt
#  833 -16 0
# connect tiles 3 4
# /content/granuleCell63XStart/stitchRes.3.4.txt
#  -21 -1115 2
# connect tiles 4 1
# /content/granuleCell63XStart/stitchRes.4.1.txt
#  -833 17 0
# 21 1131 0
# 854 1115 0
# 833 0 2
# 0 17 2
# Image dimension=(1040 1388 1) type=0 number of channels=3
# Saving combined projection image to /content/granuleCell63XStart/granule-.flatCombined.tif
# Saving the coordinates to /content/granuleCell63XStart/granule-.StitchCoord.txt
# Writing the json file for the reconstruction GUI /content/granuleCell63XStart/granule-.tiles.json
# granule-

# %% [markdown]
# ## The main show
#
# ShuTuAutoTrace is the main show and here is where that comes into play.
#
# Next in the ShuTu tutorial is #4, quoting:
# ```
# [4] Auto reconstruction:
# mpirun -n 4 ./ShuTuAutoTrace ~/granuleCell63XStart/ ShuTu.Parameters.granule63XTest.dat
# ```
#
# So, for Colab set # of processors to 1 and add the `--allow-run-as-root`.
#
# Eventually after many messages, the following should end in "Creating swc file... Saving SWC to /content/granuleCell63XStart/granule-.auto.swc
# There 48 segments 4 trees"
#
# That SWC file is the whole goal of this notebook.

# %%
# %%shell
# cd ShuTuUbuntu
# mpirun --allow-run-as-root -n 1 ./ShuTuAutoTrace /content/granuleCell63XStart/ ShuTu.Parameters.granule63XTest.dat
# Out:
# Number of tasks= 1 My rank= 0 Running on 23b2ea86b11a
# Tracing neuron from tif stacks in /content/granuleCell63XStart/
# Reading parameters from file ShuTu.Parameters.granule63XTest.dat
# The important parameters are:
# 1. xyDist		= 0.103 micron
# 2. zDist		= 0.500 micron
# 3. nSplit		=1
# 4. sparse		= 0.100
# 5. levelSetIter		=500
# 6. smallLen		=9 pixel
# 7. zJumpFact		= 5.000
# 8. distFactConn		= 2.000
# 9. minDistConn		=29.126 pixels
# 10. angle		=60.000 degree
# 11. searchMax		=48.544
# 12. factSigmaDD		=20.000
# 13. factExpandConn	= 1.000
# 14. sigmaSmoothCurve	= 1.942 pixel
# 15. sigma		= 0.030
# 16. factSigmaThreshold	= 0.300
# 17. factSigmaThreStrict	= 2.000
# 18. zOcc		=10 plane
# 19. minNumPointsBr	=5
# 20. minLenBrIso		=20.000000 micron
# 21. somaSparseThr	=0.010000
# 22. factSigmaThresholdZ	= 1.000
#
# Seldom changed parameters are:
# 23. maxFracTotPoints	= 0.500
# 24. zext		=6 plane
# 25. sigmaFilter		= 0.971 pixel
# 26. sigmaBack		=19.417 pixel
# 27. smallArea		=94 pixel^2
# 28. lambdaRatioThr	= 1.000
# 29. levelSetMu		= 0.100
# 30. factSearchMin	= 1.200
# 31. minRange		=19 pixel
# 32. minRadius		=2 pixel
# 33. maxRadius		=97 pixel
# 34. factShift		= 2.000
# 35. factAdjustRadius	= 1.000
# 36. factMarkOccXY	= 1.500
# 37. somaLengthScale	=19 pixel
# 38. alphaDistance	=20.000000
# 39. factSmallDerivZ	= 0.100
# 40. sigmaSmoothCurveZ	= 2.000 plane
# Bright field image.
# Tracing neurons with filenameCommon = /content/granuleCell63XStart/granule-
# Reading tile coordinates from /content/granuleCell63XStart/granule-.StitchCoord.txt
# Number of tiles = 4 tiff stack dimensions=(1040, 1388, 1)
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-2.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Creating mask....
# thrSparse=0.002708
# In sparseFieldLevelset...Removing small areas ...
# thrSpase=0.002708 points in skeleton=26116
# Getting linked points...
# tcmalloc: large alloc 1489715200 bytes == 0x5613f5366000 @  0x7ff817d641e7 0x561393f614ae 0x561393f43ce3 0x7ff8170b2b97 0x561393f42eba
# npoints=640
# tcmalloc: large alloc 1489715200 bytes == 0x5613f52f8000 @  0x7ff817d641e7 0x561393f643f9 0x561393f43d59 0x7ff8170b2b97 0x561393f42eba
# No soma. sqrt(nn)=1 PARAMS.somaLengthScale=19
# npoints=640
# Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# tcmalloc: large alloc 1489715200 bytes == 0x5613f52f8000 @  0x7ff817d641e7 0x561393f67c5d 0x561393f43de2 0x7ff8170b2b97 0x561393f42eba
# add 9 points...add 2 points...add 19 points...add 15 points...add 7 points...add 2 points...add 5 points...add 3 points...add 4 points...add 3 points...add 5 points...add 1 points...Reached max MAXREC, stop. add 20 points...Reached max MAXREC, stop. add 20 points...add 2 points...add 1 points...add 4 points...add 1 points...add 1 points...add 1 points...add 1 points...add 11 points...add 1 points...add 1 points...add 6 points...add 17 points...add 10 points...add 6 points...add 1 points...add 15 points...add 2 points...add 1 points...add 7 points...add 12 points...add 3 points...add 3 points...add 1 points...add 2 points...add 1 points...add 1 points...add 3 points...add 1 points...add 4 points...add 2 points...add 1 points...add 2 points...add 2 points...Reached max MAXREC, stop. add 20 points...add 11 points...add 12 points...add 4 points...add 2 points...add 1 points...add 1 points...add 7 points...add 3 points...Reached max MAXREC, stop. add 20 points...add 5 points...add 1 points...add 14 points...add 2 points...add 1 points...add 1 points...add 1 points...add 1 points...add 10 points...add 1 points...add 1 points...add 2 points...add 1 points...add 1 points...add 14 points...add 7 points...add 7 points...add 2 points...add 1 points...add 7 points...Reached max MAXREC, stop. Reached max MAXREC, stop. add 21 points...add 1 points...add 3 points...add 10 points...add 2 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 22 points...add 1 points...add 1 points...add 1 points...add 13 points...Reached max MAXREC, stop. Reached max MAXREC, stop. add 21 points...add 2 points...add 4 points...add 2 points...add 15 points...add 3 points...add 10 points...re-do growth due to reaching recursion limit. add 11 points...add 6 points...add 8 points...add 3 points...Total points added: 563
# rank=0 npoints=1176
# Saving linked points to /content/granuleCell63XStart/granule-2.tif.linkedPoints.dat...
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-3.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Creating mask....
# thrSparse=0.003168
# In sparseFieldLevelset...Removing small areas ...
# thrSpase=0.003168 points in skeleton=21181
# Getting linked points...
# npoints=544
# No soma. sqrt(nn)=1 PARAMS.somaLengthScale=19
# npoints=544
# Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 18 points...add 8 points...add 1 points...add 4 points...add 1 points...add 16 points...add 3 points...add 2 points...add 1 points...add 1 points...add 3 points...add 1 points...add 5 points...add 1 points...add 6 points...add 2 points...add 1 points...add 7 points...add 1 points...add 1 points...add 1 points...add 4 points...add 2 points...add 4 points...add 3 points...add 10 points...add 3 points...add 3 points...add 1 points...add 12 points...add 1 points...add 8 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 23 points...add 1 points...add 17 points...add 3 points...add 8 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 6 points...add 1 points...add 1 points...add 1 points...add 1 points...add 12 points...add 5 points...add 17 points...add 1 points...add 1 points...add 5 points...add 1 points...add 1 points...add 1 points...add 10 points...add 5 points...add 1 points...add 1 points...Reached max MAXREC, stop. Reached max MAXREC, stop. add 21 points...add 9 points...add 2 points...re-do growth due to reaching recursion limit. Total points added: 295
# rank=0 npoints=812
# Saving linked points to /content/granuleCell63XStart/granule-3.tif.linkedPoints.dat...
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-4.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Creating mask....
# thrSparse=0.002787
# In sparseFieldLevelset...Removing small areas ...
# thrSpase=0.002787 points in skeleton=33454
# Getting linked points...
# npoints=865
# No soma. sqrt(nn)=7 PARAMS.somaLengthScale=19
# npoints=865
# Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 2 points...add 2 points...add 2 points...add 1 points...add 1 points...add 5 points...add 2 points...add 2 points...add 3 points...add 1 points...add 3 points...add 2 points...add 3 points...add 4 points...add 1 points...add 4 points...add 2 points...add 2 points...add 2 points...add 2 points...add 1 points...add 1 points...Reached max MAXREC, stop. add 20 points...add 3 points...add 2 points...add 1 points...add 6 points...add 9 points...add 1 points...add 7 points...add 1 points...add 2 points...add 2 points...add 3 points...add 1 points...add 2 points...add 3 points...add 1 points...add 3 points...add 2 points...add 1 points...add 3 points...add 9 points...add 1 points...add 2 points...add 5 points...add 2 points...add 15 points...add 2 points...add 15 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 5 points...add 1 points...add 4 points...add 1 points...add 1 points...add 1 points...add 1 points...add 1 points...add 3 points...add 1 points...add 3 points...add 1 points...add 1 points...add 1 points...add 3 points...add 1 points...add 1 points...add 1 points...add 1 points...add 2 points...add 3 points...add 6 points...add 4 points...add 13 points...add 11 points...add 2 points...add 2 points...add 3 points...add 2 points...Reached max MAXREC, stop. add 20 points...add 9 points...add 1 points...add 9 points...re-do growth due to reaching recursion limit. add 2 points...add 1 points...Total points added: 303
# rank=0 npoints=1155
# Saving linked points to /content/granuleCell63XStart/granule-4.tif.linkedPoints.dat...
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-1.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Creating mask....
# thrSparse=0.002622
# In sparseFieldLevelset...Removing small areas ...
# thrSpase=0.002622 points in skeleton=44366
# Getting linked points...
# npoints=993
# added =10 soma points npoints=1003
# Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 9 points...add 15 points...add 2 points...add 2 points...add 17 points...add 1 points...add 6 points...add 4 points...add 3 points...add 1 points...add 17 points...add 1 points...add 1 points...add 1 points...add 2 points...add 3 points...add 1 points...add 2 points...add 2 points...add 2 points...add 12 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 23 points...add 10 points...add 1 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 22 points...add 12 points...add 2 points...add 2 points...add 1 points...add 2 points...add 3 points...add 16 points...add 19 points...add 3 points...add 9 points...add 4 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 23 points...add 5 points...add 2 points...add 2 points...add 1 points...add 4 points...add 1 points...add 2 points...add 3 points...add 2 points...add 2 points...add 1 points...add 2 points...add 4 points...add 5 points...add 3 points...add 2 points...add 4 points...add 1 points...add 9 points...add 1 points...add 1 points...add 8 points...add 2 points...add 1 points...add 2 points...add 2 points...add 2 points...add 1 points...Reached max MAXREC, stop. add 20 points...add 1 points...add 2 points...add 1 points...Reached max MAXREC, stop. add 20 points...Reached max MAXREC, stop. add 20 points...add 4 points...add 7 points...Reached max MAXREC, stop. add 20 points...add 2 points...Reached max MAXREC, stop. Reached max MAXREC, stop. add 21 points...add 5 points...Reached max MAXREC, stop. add 20 points...add 1 points...add 12 points...add 2 points...add 12 points...add 18 points...add 1 points...add 2 points...add 1 points...add 6 points...add 4 points...add 1 points...Reached max MAXREC, stop. add 20 points...add 5 points...add 3 points...add 1 points...add 1 points...add 1 points...add 4 points...add 2 points...add 3 points...add 3 points...add 5 points...add 2 points...add 1 points...add 1 points...add 2 points...add 3 points...add 2 points...add 6 points...add 2 points...add 2 points...add 4 points...add 3 points...add 2 points...add 5 points...re-do growth due to reaching recursion limit. add 2 points...add 9 points...add 7 points...Reached max MAXREC, stop. Reached max MAXREC, stop. add 21 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 22 points...add 11 points...add 3 points...Reached max MAXREC, stop. Reached max MAXREC, stop. add 21 points...re-do growth due to reaching recursion limit. add 10 points...add 8 points...Total points added: 731
# rank=0 npoints=1700
# Saving linked points to /content/granuleCell63XStart/granule-1.tif.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-2.tif.linkedPoints.dat...npoints=1176 ns=11728
# Reading linked points from /content/granuleCell63XStart/granule-3.tif.linkedPoints.dat...npoints=812 ns=8090
# Reading linked points from /content/granuleCell63XStart/granule-4.tif.linkedPoints.dat...npoints=1155 ns=11492
# Reading linked points from /content/granuleCell63XStart/granule-1.tif.linkedPoints.dat...npoints=1700 ns=16996
# Rank=0 Total number of points=4843 linkedPSize=16996
# Reading linked points from /content/granuleCell63XStart/granule-2.tif.linkedPoints.dat...
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Reading linked points from /content/granuleCell63XStart/granule-3.tif.linkedPoints.dat...
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Reading linked points from /content/granuleCell63XStart/granule-4.tif.linkedPoints.dat...
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Reading linked points from /content/granuleCell63XStart/granule-1.tif.linkedPoints.dat...
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Growing from end points in each tile....
# For growth, expand npoints by a factor 5
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3108 ns=30964
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-2.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 6 points...add 5 points...add 1 points...Total points added: 12
# Proc rank=0 created 12 points
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3105 ns=30994
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-3.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 1 points...add 2 points...add 6 points...add 4 points...add 5 points...add 1 points...add 2 points...add 1 points...add 1 points...add 1 points...add 13 points...Total points added: 37
# Proc rank=0 created 37 points
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3141 ns=31390
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-4.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 2 points...add 1 points...add 4 points...add 1 points...add 3 points...Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. Reached max MAXREC, stop. add 23 points...add 1 points...re-do growth due to reaching recursion limit. Total points added: 35
# Proc rank=0 created 35 points
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3176 ns=31762
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-1.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Deleting sharp turns (angle <60.000000 degrees) in xy ...
# Growing from the end points...
# add 2 points...add 1 points...add 1 points...add 1 points...add 4 points...add 2 points...add 2 points...Total points added: 13
# Proc rank=0 created 13 points
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3189 ns=31906
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3189 ns=31906
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3189 ns=31906
# For connecting ends, making searchMax and distFactor by a factor of 1.000000
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-2.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Connecting ends...
# Proc rank=0 made 86 connections
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-3.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Connecting ends...
# Proc rank=0 made 34 connections
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-4.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Connecting ends...
# Proc rank=0 made 66 connections
# Proc rank=0 Loading image from /content/granuleCell63XStart/granule-1.tif
# Image dimension=(1040 1388 129) type=0 number of channels=3
# Color stack. Smoothing in each plane... Bright field image. normalize maximum intensity to 1...Connecting ends...
# Proc rank=0 made 92 connections
# Saving linked points to /content/granuleCell63XStart/granule-.linkedPoints.dat...
# Reading linked points from /content/granuleCell63XStart/granule-.linkedPoints.dat...
# npointsTot=3189 ns=32184
# Creating swc file...
# Deleting small branches of length 1...Deleting connections to the deleted points...Deleting points...Deleted 125 points. npoints=3064
# Deleting small branches of length 2...Deleting connections to the deleted points...Deleting points...Deleted 36 points. npoints=3028
# Deleting small branches of length 3...Deleting connections to the deleted points...Deleting points...Deleted 21 points. npoints=3007
# Deleting small branches of length 4...Deleting connections to the deleted points...Deleting points...Deleted 22 points. npoints=2985
# Deleting small branches of length 5...Deleting connections to the deleted points...Deleting points...Deleted 11 points. npoints=2974
# Removing connected points if the total length is smaller than 20.000000 micron...Deleted 223 noisy points.
# Delete isolated branches with length smaller than 20.000000 and leaf branch smaller than 5
# Saving SWC to /content/granuleCell63XStart/granule-.auto.swc
# There 48 segments 4 trees

# %%
# Let's download that SWC before it gets thrown away after a max of 12 hours.
from google.colab import files
files.download('/content/granuleCell63XStart/granule-.auto.swc')

# %% [markdown]
# Next in the ShuTu tutorial is an explanation of that process.sh file:
# > These commands can be combined into a single script [see script process.sh].
#
# So, that `process.sh` that was written earlier by `build.sh`. Which is pretty much exactly equivalent to the code just worked through in this notebook, but as a shell script not a Jupyter notebook:
# ```
# #!/bin/bash
# set -e
# if [ $# -lt 4 ]; then
#   echo "Usage: ./process.sh <data_dir> <common_name> <param_file> <num_proc>"
#   exit 1
# fi
# dataDir=$1
# commonName=$2
# paramFile=$3
# numproc=$4
# mpirun -n $numproc ./createTiffStacksZeiss $dataDir $commonName
# mpirun -n $numproc ./processImages $dataDir
# mpirun -n $numproc ./stitchTiles $dataDir
# mpirun -n $numproc ./ShuTuAutoTrace $dataDir $paramFile
# ```

# %% [markdown]
# For Colab set num_proc to 1.

# %%
# !ls content/granuleCell63XStart/granule-.auto.swc

# %% [markdown]
# # ------------
# # clipped from other docs
# ## build.sh becomes a Colab code cell
#
# The above `wget` and `unzip` should run uneventfully.
#
# ### The out-of-the-box way
# The next big thing is to run `build.sh` which will hang on an error but it's harmless. The script is done when it hangs at:
# ```
# mpicc -o scaleSWC scaleSWC.o libShuTu.o -Lmylib -lmylib -lm
# bash: cannot set terminal process group (118): Inappropriate ioctl for device
# bash: no job control in this shell
# root@55ff33362eac:/content/ShuTuUbuntu#
# ```
# But that last thing `build.sh` does is write a file called `process.sh` and that file gets written, so that's how to detect if it worked.

# %%
# %%shell
#
# set -m # needed to avoid error: bash: no job control in this shell
# cd ShuTuUbuntu
#
# # This next line will work OK, but will hang on a harmless error message
# ./build.sh

# %% [markdown]
# ## Features
#
# This is just a dumping ground for random ideas. Nothing herein is yet planned for developement.
#
# - [Document how to set up ShuTu desktop viewer](https://github.com/reconstrue/brightfield_neuron_reconstruction/issues/2)

# %% [markdown]
# from The Allen Institute's challenge dataset.
#
# This is the main notebook for processing Allen Institute's BioImage challenge data using ShuTu to generate the SWC file.
#
# The code in this Jupyter notebook has been tested to run on Google's Colab site.
#
#
#
#
#
#
# ### Cut?
# This project runs ShuTu's SWC generator on Colab. Optionally one can easily download the ShuTu generated SWC, and view it in ShuTu's SWC editor GUI application running on localhost.  ShuTu's desktop application is very easy to install on Linux and Mac, Windows looks to be a bit more work, but seemingly can be done (dunno, haven't tested).
